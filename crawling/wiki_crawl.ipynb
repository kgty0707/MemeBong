# %% [markdown]
# https://namu.wiki/robots.txt
#
# User-agent: *
# Disallow: /
# Allow: /$
# Allow: /ads.txt
# Allow: /w/
# Allow: /history/
# Allow: /backlink/
# Allow: /OrphanedPages
# Allow: /UncategorizedPages
# Allow: /ShortestPages
# Allow: /LongestPages
# Allow: /RecentChanges
# Allow: /RecentDiscuss
# Allow: /Search
# Allow: /discuss/
# Allow: /js/
# Allow: /img/
# Allow: /css/
# Allow: /skins/
# Allow: /favicon.ico
# Allow: /_nuxt/
# Allow: /sidebar.json
# Allow: /cdn-cgi/

# %%
import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import json
import re
from datetime import datetime
import pandas as pd
import time
from urllib.parse import urljoin

class MemeCrawler:
    def __init__(self):
        self.base_url = "https://namu.wiki"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        self.session = requests.Session()
        self.session.headers.update(self.headers)

    def get_page_content(self, url):
        """웹 페이지의 콘텐츠를 가져옵니다."""
        try:
            print(f"🌐 페이지 요청 중: {url}")
            response = self.session.get(url)
            response.raise_for_status()
            print(f"✅ 페이지 로딩 성공 (상태 코드: {response.status_code})")
            return BeautifulSoup(response.content, 'html.parser')
        except requests.exceptions.RequestException as e:
            print(f"❌ 페이지 요청 실패: {url}, 오류: {e}")
            return None

    def _process_meme_elements(self, elements):
        """
        한 밈을 구성하는 HTML 요소 리스트를 받아 title과 link 정보를 추출합니다.
        [<a..>류정란</a>, ' 챌린지'] -> ("류정란 챌린지", {"류정란": "http..."})
        """
        if not elements:
            return None, None

        # 1. 모든 텍스트 조각을 합쳐 완전한 title 생성
        title_parts = []
        for el in elements:
            text = el.get_text() if isinstance(el, Tag) else str(el)
            title_parts.append(text)
        full_title = "".join(title_parts).strip()

        # 2. 링크 정보를 딕셔너리로 추출
        related_links = {}
        for el in elements:
            if isinstance(el, Tag) and el.name == 'a':
                href = el.get('href', '')
                if href and not href.startswith('#fn-'):
                    linked_text = el.get_text(strip=True)
                    full_url = urljoin(self.base_url, href)
                    related_links[linked_text] = full_url
        
        return (full_title, related_links) if full_title else (None, None)

    def parse_meme_list(self, content_divs, year_main):
        """주어진 대분류(year_main)에 대해 콘텐츠 div 목록을 파싱합니다."""
        memes = []
        current_sub_year = year_main

        for div in content_divs:
            text_content = div.get_text(strip=True)
            if not text_content:
                continue

            # Case 1: 소분류 연도 헤더 (예: "2015년")
            year_match = re.fullmatch(r'(\d{4}년)', text_content)
            if year_match:
                current_sub_year = year_match.group(1)
                print(f"  ➡️  소분류 연도 업데이트: {current_sub_year}")
                continue

            # Case 2: 월별 밈 데이터 (":" 포함)
            if ':' in text_content:
                month = text_content.split(':', 1)[0].strip()
                
                # 현재 밈을 구성하는 요소들을 임시 저장하는 리스트
                current_meme_elements = []
                
                # 첫 텍스트 요소에서 '월:' 부분 제거
                if div.contents and isinstance(div.contents[0], NavigableString):
                    if ':' in div.contents[0]:
                        cleaned_first_element = str(div.contents[0]).split(':', 1)[1]
                        div.contents[0].replace_with(NavigableString(cleaned_first_element))

                # 쉼표(,)를 기준으로 밈을 나누어 처리
                for element in div.contents:
                    if isinstance(element, NavigableString) and ',' in str(element):
                        parts = str(element).split(',')
                        
                        # 쉼표 앞부분을 현재 밈에 추가하고 하나의 밈으로 완성
                        current_meme_elements.append(NavigableString(parts[0]))
                        title, links = self._process_meme_elements(current_meme_elements)
                        if title:
                            memes.append({
                                'year_main': year_main, 'year_sub': current_sub_year, 'month': month,
                                'title': title, 'related_links': links, 'crawled_at': datetime.now().isoformat()
                            })
                            print(f"  ✅ [밈 추출] {title}")

                        # 쉼표로만 구분된 텍스트 밈들 처리
                        for middle_part in parts[1:-1]:
                            title, links = self._process_meme_elements([NavigableString(middle_part)])
                            if title:
                                memes.append({
                                    'year_main': year_main, 'year_sub': current_sub_year, 'month': month,
                                    'title': title, 'related_links': links, 'crawled_at': datetime.now().isoformat()
                                })
                                print(f"  ✅ [밈 추출] {title}")
                        
                        # 다음 밈을 위해 마지막 조각으로 리스트 초기화
                        current_meme_elements = [NavigableString(parts[-1])]
                    else:
                        # 쉼표가 없는 요소는 현재 밈에 계속 추가
                        current_meme_elements.append(element)
                
                # 마지막으로 남아있는 밈 처리
                if current_meme_elements:
                    title, links = self._process_meme_elements(current_meme_elements)
                    if title:
                        memes.append({
                            'year_main': year_main, 'year_sub': current_sub_year, 'month': month,
                            'title': title, 'related_links': links, 'crawled_at': datetime.now().isoformat()
                        })
                        print(f"  ✅ [밈 추출] {title}")
        return memes

    def crawl_all_memes(self):
        """모든 데이터 컨테이너를 찾아 밈을 크롤링합니다."""
        target_url = "https://namu.wiki/w/밈(인터넷%20용어)"
        soup = self.get_page_content(target_url)
        if not soup:
            return []

        all_memes = []
        
        content_wrappers = soup.select('div.W1ezmmoN')
        print(f"\n🚀 총 {len(content_wrappers)}개의 데이터 컨테이너를 찾았습니다.")

        for wrapper in content_wrappers:
            heading_tag = wrapper.find_previous(['h1', 'h2', 'h3', 'h4', 'h5'])
            
            if heading_tag:
                year_main = heading_tag.get_text(strip=True).split('[')[0]
            else:
                year_main = 'Unknown Section'

            print(f"\n{'='*60}\n🔍 섹션 처리 중: '{year_main}'\n{'='*60}")
            
            content_divs = wrapper.select('div.RhzQ8fAX')
            memes_from_block = self.parse_meme_list(content_divs, year_main)
            all_memes.extend(memes_from_block)
            
            time.sleep(0.1)

        return all_memes

    def save_to_file(self, data, filename_base='memes_final'):
        """데이터를 JSON과 CSV 파일로 저장합니다."""
        if not data:
            print("⚠️ 수집된 데이터가 없어 저장할 수 없습니다.")
            return

        # JSON으로 저장 (딕셔너리를 문자열로 변환하여 저장)
        for item in data:
            if 'related_links' in item and isinstance(item['related_links'], dict):
                item['related_links'] = json.dumps(item['related_links'], ensure_ascii=False)

        json_filename = f"{filename_base}.json"
        with open(json_filename, 'w', encoding='utf-8') as f:
            # 원본 데이터를 다시 로드하여 JSON에 예쁘게 저장
            df = pd.DataFrame(data)
            records = df.to_dict('records')
            json.dump(records, f, ensure_ascii=False, indent=2)
        print(f"\n💾 데이터가 {json_filename} 파일로 저장되었습니다.")

        # CSV로 저장
        csv_filename = f"{filename_base}.csv"
        df = pd.DataFrame(data)
        df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
        print(f"💾 데이터가 {csv_filename} 파일로 저장되었습니다.")

# --- 메인 실행 블록 ---
def main():
    crawler = MemeCrawler()
    
    print("🎭 나무위키 밈 크롤러를 시작합니다...")
    memes_data = crawler.crawl_all_memes()
    
    if memes_data:
        print(f"\n🎉 크롤링 완료! 총 {len(memes_data)}개의 밈을 수집했습니다.")
        
        crawler.save_to_file(memes_data)
        
        print("\n📋 수집된 데이터 샘플 (마지막 5개):")
        df = pd.DataFrame(memes_data)
        print(df.tail().to_string())
    else:
        print("\n❌ 데이터를 수집하지 못했습니다. 웹사이트 구조가 변경되었을 수 있습니다.")

if __name__ == "__main__":
    main()
# Out:
# 🎭 나무위키 밈 크롤러를 시작합니다...
# 🌐 페이지 요청 중: https://namu.wiki/w/밈(인터넷%20용어)
# ✅ 페이지 로딩 성공 (상태 코드: 200)
#
# 🚀 총 56개의 데이터 컨테이너를 찾았습니다.
#
# ============================================================
# 🔍 섹션 처리 중: '1.개요'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '2.문화적 특징'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '3.역사'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '4.밈의 수명'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '5.국가별 밈 목록'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '5.1.대한민국'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '5.2.해외'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '5.2.1.일본'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.파생된 밈'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.1.Geometry Dash계열'
# ============================================================
#   ✅ [밈 추출] Knobbelboy
#
# ============================================================
# 🔍 섹션 처리 중: '6.2.Grand Theft Auto 시리즈계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.3.네모바지 스폰지밥계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.4.드래곤볼계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.5.릭 앤 모티'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.6.마다가스카의 펭귄계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.7.마리오 시리즈계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.8.마인크래프트계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.9.블루 아카이브계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.10.별의 커비 시리즈계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.11.소닉 더 헤지혹 시리즈계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.12.팩맨 시리즈계열'
# ============================================================
#   ✅ [밈 추출] 새로운 모험)
#
# ============================================================
# 🔍 섹션 처리 중: '6.13.슈렉 시리즈계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.14.스타워즈계열'
# ============================================================
#   ✅ [밈 추출] 로그 원: 스타워즈 스토리
#
# ============================================================
# 🔍 섹션 처리 중: '6.15.심슨 가족계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.16.유튜브 리와인드2018'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.17.이니셜 D계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.18.포켓몬스터계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.19.레인보우 식스 시즈계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '6.20.팀 포트리스 2계열'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '7.시기별 유행 밈'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.대한민국'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.1.2010년 이전'
# ============================================================
#   ➡️  소분류 연도 업데이트: 1997년
#   ✅ [밈 추출] 무대뽀
#   ✅ [밈 추출] 헝그리 정신
#   ➡️  소분류 연도 업데이트: 1999년
#   ✅ [밈 추출] 디지몬 어드벤처
#   ✅ [밈 추출] 볼레로
#   ✅ [밈 추출] 난 한 놈만 패
#   ➡️  소분류 연도 업데이트: 2001년
#   ✅ [밈 추출] 느그 아부지 뭐하시노
#   ✅ [밈 추출] 성지순례
#   ✅ [밈 추출] 내가 제일 존경하는 오사마 빈 라덴[34]
#   ✅ [밈 추출] 초성어[35]
#   ➡️  소분류 연도 업데이트: 2002년
#   ✅ [밈 추출] 안톤 오노
#   ✅ [밈 추출] 붉은악마
#   ✅ [밈 추출] 압박
#   ✅ [밈 추출] 오 필승 코리아
#   ✅ [밈 추출] 옥동자
#   ✅ [밈 추출] 개죽이
#   ✅ [밈 추출] 긴또깡
#   ✅ [밈 추출] 짤방[36]
#   ✅ [밈 추출] 내 아를 낳아도
#   ✅ [밈 추출] 불심으로 대동단결
#   ➡️  소분류 연도 업데이트: 2003년
#   ✅ [밈 추출] 맞습니다 맞고요
#   ✅ [밈 추출] 뷁
#   ✅ [밈 추출] 밥은 먹고 다니냐
#   ✅ [밈 추출] 두 번 죽이는 거
#   ✅ [밈 추출] 숫자송
#   ✅ [밈 추출] 어 작업중이야[37]
#   ✅ [밈 추출] 을용타
#   ➡️  소분류 연도 업데이트: 2004년
#   ✅ [밈 추출] 이 안에 너 있다
#   ✅ [밈 추출] 파맛 첵스
#   ✅ [밈 추출] 적절하다
#   ➡️  소분류 연도 업데이트: 2005년
#   ✅ [밈 추출] 술은 마셨지만 음주운전은 하지 않았다
#   ✅ [밈 추출] 신돈
#   ✅ [밈 추출] 허이짜
#   ➡️  소분류 연도 업데이트: 2006년
#   ✅ [밈 추출] 미녀는 석류를 좋아해
#   ✅ [밈 추출] 바이오하자드 4 Mindless Self Indulgence Shue Me Up 매드 무비
#   ➡️  소분류 연도 업데이트: 2007년
#   ✅ [밈 추출] 망했어요
#   ✅ [밈 추출] 나는 관대하다
#   ✅ [밈 추출] 아시발꿈
#   ✅ [밈 추출] 빵상 아줌마
#   ✅ [밈 추출] 여러분 이거 다 거짓말인 거 아시죠
#   ✅ [밈 추출] 블리치 소울 소사이어티 AMV
#   ✅ [밈 추출] 데스노트/애니메이션
#   ✅ [밈 추출] 카르미나 부라나 중 O Fortuna
#   ✅ [밈 추출] 바카야로이드
#   ✅ [밈 추출] 도박묵시록 카이지/애니메이션(인간 관악기 MAD 포함)
#   ➡️  소분류 연도 업데이트: 2008년
#   ✅ [밈 추출] 야 기분 좋다
#   ✅ [밈 추출] 현기증 난단 말이에요
#   ✅ [밈 추출] 어둠의 다크에서 죽음의 데스를 느끼며
#   ✅ [밈 추출] 빠삐놈
#   ✅ [밈 추출] 까방권
#   ✅ [밈 추출] 두뇌 풀 가동!
#   ✅ [밈 추출] ONE OUTS/애니메이션
#   ➡️  소분류 연도 업데이트: 2009년
#   ✅ [밈 추출] Plants vs Zombies
#   ✅ [밈 추출] 꿀벅지
#   ✅ [밈 추출] 컨트리볼
#   ✅ [밈 추출] 폴란드볼
#   ✅ [밈 추출] 인실좆
#   ✅ [밈 추출] 루저의 난
#   ✅ [밈 추출] 빵꾸똥꾸
#   ✅ [밈 추출] 빵셔틀
#   ✅ [밈 추출] 한 뚝배기 하실래예[38]
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.2.2010년~2014년'
# ============================================================
#   ➡️  소분류 연도 업데이트: 2010년
#   ✅ [밈 추출] 넌 나에게 모욕감을 줬어[39]
#   ✅ [밈 추출] 돋네
#   ✅ [밈 추출] 박대기
#   ✅ [밈 추출] 오덕페이트
#   ✅ [밈 추출] 코렁탕
#   ✅ [밈 추출] 삼일절 사이버 전쟁[40]
#   ✅ [밈 추출] 아모캣[41]
#   ✅ [밈 추출] 에바
#   ✅ [밈 추출] 함정카드 밈
#   ✅ [밈 추출] 꼽등이
#   ✅ [밈 추출] 아직 한 발 남았다[42]
#   ✅ [밈 추출] 힙통령
#   ✅ [밈 추출] 꽈찌쭈
#   ✅ [밈 추출] 아니 없어요 그냥
#   ✅ [밈 추출] 종범
#   ➡️  소분류 연도 업데이트: 2011년
#   ✅ [밈 추출] 간 때문이야
#   ✅ [밈 추출] 씹선비
#   ✅ [밈 추출] 너 고소
#   ✅ [밈 추출] Nyan Cat
#   ✅ [밈 추출] 김치녀
#   ✅ [밈 추출] 내가 제일 잘 나가
#   ✅ [밈 추출] 개 짖는 소리 좀 안 나게 하라
#   ✅ [밈 추출] 11미터 모형탑 훈련
#   ✅ [밈 추출] 더 이상의 자세한 설명은 생략한다.
#   ✅ [밈 추출] 이 차는 이제 제 겁니다
#   ✅ [밈 추출] 이봐요 미친놈씨
#   ✅ [밈 추출] 도지삽니다
#   ➡️  소분류 연도 업데이트: 2012년
#   ✅ [밈 추출] MC무현
#   ✅ [밈 추출] 뽐거지
#   ✅ [밈 추출] 느그 서장 남천동 살제?
#   ✅ [밈 추출] 작은 하마 이야기
#   ✅ [밈 추출] 저도 참 좋아하는데요, 제가 한번 먹어보겠습니다
#   ✅ [밈 추출] 네가 하면 나도 한다
#   ✅ [밈 추출] 불닭볶음면
#   ✅ [밈 추출] 강남스타일
#   ✅ [밈 추출] 브라우니 물어
#   ✅ [밈 추출] 북경 정씨
#   ✅ [밈 추출] 무대를 뒤집어 놓으셨다
#   ✅ [밈 추출] 어서 와
#   ✅ [밈 추출] 인증 대란
#   ✅ [밈 추출] 자박꼼
#   ➡️  소분류 연도 업데이트: 2013년
#   ✅ [밈 추출] 올레 악동뮤지션 cm송
#   ✅ [밈 추출] 귀요미송
#   ✅ [밈 추출] 쿠키런
#   ✅ [밈 추출] What does the fox say?
#   ➡️  소분류 연도 업데이트: 2014년
#   ✅ [밈 추출] 명량
#   ✅ [밈 추출] 아이스버킷 챌린지
#   ✅ [밈 추출] 시간아 천천히
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.3.2015년~2017년'
# ============================================================
#   ➡️  소분류 연도 업데이트: 2015년
#   ✅ [밈 추출] sake L
#   ✅ [밈 추출] 오로나민C
#   ✅ [밈 추출] Yee
#   ✅ [밈 추출] 급식체[~2019년]
#   ✅ [밈 추출] 찰리찰리 챌린지
#   ✅ [밈 추출] 눈을 왜 그렇게 떠?
#   ✅ [밈 추출] 마이 리틀 텔레비전
#   ✅ [밈 추출] 엄청 커다란 모기가 나의 발을 물었어!
#   ✅ [밈 추출] 누가 기침 소리를 내었는가
#   ✅ [밈 추출] 나 꿈꿨어 귀신 꿈꿨어
#   ✅ [밈 추출] 어이가 없네
#   ✅ [밈 추출] 레스토랑스
#   ➡️  소분류 연도 업데이트: 2016년
#   ✅ [밈 추출] 아기상어
#   ✅ [밈 추출] 샤샤샤
#   ✅ [밈 추출] 뭣이 중헌디
#   ✅ [밈 추출] 오버워치(류승룡 기모찌!
#   ✅ [밈 추출] 겐트위한)
#   ✅ [밈 추출] 너 때문에 흥이 다 깨져버렸으니까 책임져
#   ✅ [밈 추출] PPAP
#   ✅ [밈 추출] 너굴맨
#   ✅ [밈 추출] 너무해 너무해
#   ✅ [밈 추출] 내가 이러려고 대통령을 했나
#   ➡️  소분류 연도 업데이트: 2017년
#   ✅ [밈 추출] 핵불닭볶음면
#   ✅ [밈 추출] 산타벌스
#   ✅ [밈 추출] 트로피카나 스파클링
#   ✅ [밈 추출] 항아리 게임
#   ✅ [밈 추출] 급식체(장삐쭈)
#   ✅ [밈 추출] 상상도 못한 정체
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.4.2018년'
# ============================================================
#   ✅ [밈 추출] 사랑을 했다
#   ✅ [밈 추출] 폰은정
#   ✅ [밈 추출] 였던 것 드립
#   ✅ [밈 추출] 영미
#   ✅ [밈 추출] 병신TV
#   ✅ [밈 추출] 탈모르파티
#   ✅ [밈 추출] 어벤져스: 인피니티 워
#   ✅ [밈 추출] 다 아는 사람들이구먼
#   ✅ [밈 추출] 조혜련의 태보 다이어트
#   ✅ [밈 추출] 나는 예쁘지 않습니다
#   ✅ [밈 추출] 오또케
#   ✅ [밈 추출] He is ○○
#   ✅ [밈 추출] 착짱죽짱
#   ✅ [밈 추출] 조혜련과 태보의 저주
#   ✅ [밈 추출] 야 XX
#   ✅ [밈 추출] 껍질 미리 깐 달걀
#   ✅ [밈 추출] 전국 handclap 자랑
#   ✅ [밈 추출] 소년점프
#   ✅ [밈 추출] SKY 캐슬(We All Lie
#   ✅ [밈 추출] 아갈머리
#   ✅ [밈 추출] 피라미드
#   ✅ [밈 추출] 쓰앵님
#   ✅ [밈 추출] 혜나는 누가 죽였나요)
#   ✅ [밈 추출] 핵인싸
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.5.2019년'
# ============================================================
#   ✅ [밈 추출] 절대태보해
#   ✅ [밈 추출] 치카 댄스
#   ✅ [밈 추출] 대충 드립
#   ✅ [밈 추출] 자전차왕 엄복동
#   ✅ [밈 추출] 안녕하살법
#   ✅ [밈 추출] 브롤스타즈 레온 옷
#   ✅ [밈 추출] 버억
#   ✅ [밈 추출] 힘들지 않아 거친 정글 속에 뛰어든 건 나니까 암오케
#   ✅ [밈 추출] 나도 내가 징징거리고 눈꼴시려운건 알고 있는데
#   ✅ [밈 추출] 쁘악수
#   ✅ [밈 추출] 기생충
#   ✅ [밈 추출] Woman Yelling at a Cat
#   ✅ [밈 추출] 틀니 2주 압수
#   ✅ [밈 추출] 일본 불매운동
#   ✅ [밈 추출] 날강두
#   ✅ [밈 추출] 이 시국에
#   ✅ [밈 추출] 인사하는 제리
#   ✅ [밈 추출] 이이잉 앗살라말라이쿰
#   ✅ [밈 추출] 곽철용
#   ✅ [밈 추출] 유튜브 알고리즘
#   ✅ [밈 추출] 여름이었다
#   ✅ [밈 추출] 잼민이
#   ✅ [밈 추출] 오뚝이 다트
#   ✅ [밈 추출] 찌리찌리
#   ✅ [밈 추출] 헬창
#   ✅ [밈 추출] 국밥충
#   ✅ [밈 추출] 어벤져스: 엔드게임
#   ✅ [밈 추출] 모기송
#   ✅ [밈 추출] 가성비 댓글
#   ✅ [밈 추출] 코리안조커
#   ✅ [밈 추출] 펭수
#   ✅ [밈 추출] 아마존 익스프레스
#   ✅ [밈 추출] 겨울왕국 2
#   ✅ [밈 추출] 단또단또
#   ✅ [밈 추출] 야나두
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.6.2020년'
# ============================================================
#   ✅ [밈 추출] 아임뚜렛
#   ✅ [밈 추출] 안전가좆물[45]
#   ✅ [밈 추출] 그랜절
#   ✅ [밈 추출] 지이잉
#   ✅ [밈 추출] 호박고구마
#   ✅ [밈 추출] 할카스
#   ✅ [밈 추출] 아무노래
#   ✅ [밈 추출] 코로나바이러스감염증-19
#   ✅ [밈 추출] 종로로 갈까요
#   ✅ [밈 추출] 만희물
#   ✅ [밈 추출] ㄷㄷㄷㅈ
#   ✅ [밈 추출] 나비보벳따우
#   ✅ [밈 추출] 죄송합니다
#   ✅ [밈 추출] 미안하다 이거 보여주려고 어그로끌었다
#   ✅ [밈 추출] 관짝춤
#   ✅ [밈 추출] 나는 개인이오
#   ✅ [밈 추출] 캬루
#   ✅ [밈 추출] 깡
#   ✅ [밈 추출] 헬테이커
#   ✅ [밈 추출] 펀쿨섹좌
#   ✅ [밈 추출] 엄준식
#   ✅ [밈 추출] ~은(는) 사드세요.....제발
#   ✅ [밈 추출] 불 좀 꺼줄래?
#   ✅ [밈 추출] 야 꿀벌
#   ✅ [밈 추출] 가면라이더 드립
#   ✅ [밈 추출] 첵스 파맛
#   ✅ [밈 추출] 군침이 싹 도노
#   ✅ [밈 추출] 가짜사나이
#   ✅ [밈 추출] 부리부리 마신 소환 춤
#   ✅ [밈 추출] ~를 알려주겠다
#   ✅ [밈 추출] 뒷광고
#   ✅ [밈 추출] 테스형!
#   ✅ [밈 추출] 애기공룡 둘리
#   ✅ [밈 추출] 돌리랑 도트가 제일 좋아
#   ✅ [밈 추출] 사실은 오래전부터 당신 같은 XXX를 기다려 왔다우
#   ✅ [밈 추출] 제주도 찐 사투리
#   ✅ [밈 추출] 어몽어스
#   ✅ [밈 추출] 빅맥송
#   ✅ [밈 추출] 다메다메
#   ✅ [밈 추출] 펫 더 피포
#   ✅ [밈 추출] 훈발놈
#   ✅ [밈 추출] 세뇌교육
#   ✅ [밈 추출] 뭉탱이
#   ✅ [밈 추출] 난 너가 줏대있게 인생 살았으면 좋겠어
#   ✅ [밈 추출] 치즈분수
#   ✅ [밈 추출] 한국인이 좋아하는 속도
#   ✅ [밈 추출] 사쿠란보
#   ✅ [밈 추출] 하츠네 형돈
#   ✅ [밈 추출] Pop Cat
#   ✅ [밈 추출] 당연히 말이 되죠
#   ✅ [밈 추출] 홍준표 2번
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.7.2021년'
# ============================================================
#   ✅ [밈 추출] 무야호
#   ✅ [밈 추출] 팝캣
#   ✅ [밈 추출] 강아지 경찰 아저씨
#   ✅ [밈 추출] 포브스 드립
#   ✅ [밈 추출] 스윗중남
#   ✅ [밈 추출] 비트 밈
#   ✅ [밈 추출] 롤린
#   ✅ [밈 추출] 삼각함수송
#   ✅ [밈 추출] 제 딸을 살해한 놈들을 15년 후에 죽여주세요
#   ✅ [밈 추출] 무한열차
#   ✅ [밈 추출] 안아줘요
#   ✅ [밈 추출] 가수 일론 머스크
#   ✅ [밈 추출] 시무라 아주머니
#   ✅ [밈 추출] LH 게이트
#   ✅ [밈 추출] 멈춰![46]
#   ✅ [밈 추출] 마이야히
#   ✅ [밈 추출] 오타쿠가 정치글을 쓰게 만드는 정부가 존재할 필요가 있나?
#   ✅ [밈 추출] 육군 we 육군
#   ✅ [밈 추출] 머니게임
#   ✅ [밈 추출] 나락송
#   ✅ [밈 추출] 아라아라
#   ✅ [밈 추출] 흔한 여고생들의 뻘짓
#   ✅ [밈 추출] 프라이데이 나이트 펑킨
#   ✅ [밈 추출] 삼성걸
#   ✅ [밈 추출] 근데 이제 뭐함?
#   ✅ [밈 추출] 넥스트 레벨
#   ✅ [밈 추출] 굿바이 선언
#   ✅ [밈 추출] 꽁기깅깅깅공강강꽁기깅깅꽁기깅강
#   ✅ [밈 추출] 제로투 댄스
#   ✅ [밈 추출] 한심좌
#   ✅ [밈 추출] 샤방송
#   ✅ [밈 추출] 똥 밟았네
#   ✅ [밈 추출] 누가 칼들고 협박함?
#   ✅ [밈 추출] 마인크래프트 19금 사태
#   ✅ [밈 추출] 2020 도쿄 올림픽 픽토그램
#   ✅ [밈 추출] 활벤져스
#   ✅ [밈 추출] 소금소금소금팥팥팥
#   ✅ [밈 추출] 잭 오
#   ✅ [밈 추출] 그런건 없다 게이야
#   ✅ [밈 추출] 성윤모
#   ✅ [밈 추출] 오징어 게임
#   ✅ [밈 추출] 앙카 존 댄스
#   ✅ [밈 추출] 라고 할 뻔
#   ✅ [밈 추출] 스트릿 우먼 파이터
#   ✅ [밈 추출] 설거지론
#   ✅ [밈 추출] 커다란 자갈돌은 짱돌
#   ✅ [밈 추출] 파피 플레이타임
#   ✅ [밈 추출] 오니기리 댄스
#   ✅ [밈 추출] 어쩔티비
#   ✅ [밈 추출] 정상수
#   ✅ [밈 추출] 몰?루
#   ✅ [밈 추출] 개같이 XX
#   ✅ [밈 추출] 북방코끼리바다표범
#   ✅ [밈 추출] 여자가⋯ 말대꾸⁈
#   ✅ [밈 추출] 요나요나 댄스
#   ✅ [밈 추출] 어느새부터 힙합은 안 멋져
#   ✅ [밈 추출] 힘숨찐
#   ✅ [밈 추출] 슈퍼 아이돌
#   ✅ [밈 추출] 사실이 아닙니다!
#   ✅ [밈 추출] 예쁘잖아
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.8.2022년'
# ============================================================
#   ✅ [밈 추출] 피에로 드립
#   ✅ [밈 추출] 미스터 인크레더블 밈
#   ✅ [밈 추출] 코카인 댄스
#   ✅ [밈 추출] 곽윤기의 뒷선수 시점
#   ✅ [밈 추출] 저 반바지 아니에요
#   ✅ [밈 추출] 포켓몬빵
#   ✅ [밈 추출] 킹근육골드몬
#   ✅ [밈 추출] 지구방위대 챌린지
#   ✅ [밈 추출] 어몽어스 잼민이
#   ✅ [밈 추출] 부럽지가 않어
#   ✅ [밈 추출] 해병문학
#   ✅ [밈 추출] 아냐 포저의 얼굴 표정
#   ✅ [밈 추출] 마이 네임 이즈 찢기
#   ✅ [밈 추출] LOVE DIVE
#   ✅ [밈 추출] 마미 롱 레그
#   ✅ [밈 추출] 소울리스좌
#   ✅ [밈 추출] That That
#   ✅ [밈 추출] 아이 러브 마이 화자 마자 브라자
#   ✅ [밈 추출] 눗눗
#   ✅ [밈 추출] 범죄도시 2
#   ✅ [밈 추출] 재즈를 뭐라고 생각하세요?
#   ✅ [밈 추출] 후드에서 살아남기
#   ✅ [밈 추출] 여기어때송
#   ✅ [밈 추출] 오붕가
#   ✅ [밈 추출] 이상한 변호사 우영우
#   ✅ [밈 추출] 닭팔이
#   ✅ [밈 추출] 모기송
#   ✅ [밈 추출] 점점 빨라지는 노래
#   ✅ [밈 추출] 제네시스좌
#   ✅ [밈 추출] 슬픈 고양이 댄스
#   ✅ [밈 추출] 인주 앨리스
#   ✅ [밈 추출] 알빠노
#   ✅ [밈 추출] 실패작 소녀
#   ✅ [밈 추출] Young한데? 완전 MZ인데요?
#   ✅ [밈 추출] 새삥
#   ✅ [밈 추출] 제로투 회피
#   ✅ [밈 추출] 중요한 것은 꺾이지 않는 마음[48]
#   ✅ [밈 추출] 갱갱갱
#   ✅ [밈 추출] 띠용흥민
#   ✅ [밈 추출] 알빠임?
#   ✅ [밈 추출] 귀여워서 미안해
#   ✅ [밈 추출] 짱구야 아빠를 속인거니?
#   ✅ [밈 추출] 오빠 오빠 차 있어?
#   ✅ [밈 추출] 뉴진스의 하입보이요
#   ✅ [밈 추출] 근데 어쩔건데?
#   ✅ [밈 추출] 폼 미쳤다
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.9.2023년'
# ============================================================
#   ✅ [밈 추출] 닛몰캐쉬
#   ✅ [밈 추출] 토카토카 댄스
#   ✅ [밈 추출] 04년생 클럽춤. 팅팅송
#   ✅ [밈 추출] 멋지다 연진아, 스튜어디스 혜정아
#   ✅ [밈 추출] 제기랄, 또 ~~~야!
#   ✅ [밈 추출] 뉴진스의 하입보이요[12월~]
#   ✅ [밈 추출] 우리 엄마엄마가
#   ✅ [밈 추출] 시그마
#   ✅ [밈 추출] 마따끄
#   ✅ [밈 추출] 나문희의 첫사랑
#   ✅ [밈 추출] 나이트 댄서
#   ✅ [밈 추출] 고도로 발달한 A는 B와 구분할 수 없다
#   ✅ [밈 추출] 스즈메의 문단속
#   ✅ [밈 추출] 뽀삐뽀삐뽀 뽀삐뽀
#   ✅ [밈 추출] 크리스천
#   ✅ [밈 추출] 봇치 밈
#   ✅ [밈 추출] 해피캣
#   ✅ [밈 추출] 이궈궈던
#   ✅ [밈 추출] 아디아디아디
#   ✅ [밈 추출] 강풍 올백
#   ✅ [밈 추출] ~한 건에 대하여
#   ✅ [밈 추출] 【최애의 아이】(삐에용 부트 댄스
#   ✅ [밈 추출] 아이돌)
#   ✅ [밈 추출] 와플
#   ✅ [밈 추출] 너 T야?
#   ✅ [밈 추출] 사카밤바스피스
#   ✅ [밈 추출] 스키비디 토일렛
#   ✅ [밈 추출] 사우스 코리안 파크
#   ✅ [밈 추출] 크아아악! XX아!
#   ✅ [밈 추출] 지구 온라인
#   ✅ [밈 추출] Gucci Boy
#   ✅ [밈 추출] 아오 페리시치
#   ✅ [밈 추출] 좋았어 영차[51]
#   ✅ [밈 추출] 엘리멘탈
#   ✅ [밈 추출] Steal The Show
#   ✅ [밈 추출] LK-99(초전도체)
#   ✅ [밈 추출] 인생 하드모드
#   ✅ [밈 추출] 모스부호
#   ✅ [밈 추출] 어 맞아맞아 놀랍지만 그건 사실이야
#   ✅ [밈 추출] 피어나 너 내 도도독
#   ✅ [밈 추출] 올리버쌤 성대모사
#   ✅ [밈 추출] 탕후루
#   ✅ [밈 추출] 워싱시
#   ✅ [밈 추출] Love Lee
#   ✅ [밈 추출] 로리신 레퀴엠
#   ✅ [밈 추출] 김도와 마즈피플
#   ✅ [밈 추출] 슬릭백
#   ✅ [밈 추출] 잘 가라, 최강. 내가 없는 시대에 태어났을 뿐인 범부여
#   ✅ [밈 추출] I am신뢰에요~
#   ✅ [밈 추출] 어머니가 계셨구나
#   ✅ [밈 추출] 똑똑한 청년.
#   ✅ [밈 추출] 장충동왕족발보쌈
#   ✅ [밈 추출] 이비온 악기
#   ✅ [밈 추출] 세 세구 라이드
#   ✅ [밈 추출] I am신뢰에요~
#   ✅ [밈 추출] 럼자오자레
#   ✅ [밈 추출] 88848
#   ✅ [밈 추출] 당근칼
#   ✅ [밈 추출] 기습숭배
#   ✅ [밈 추출] 나루토 춤[52]
#   ✅ [밈 추출] 나 XX인데 개추 눌렀다
#   ✅ [밈 추출] 조시 허처슨
#   ✅ [밈 추출] (XXX에서 연락옴)
#   ✅ [밈 추출] 치피치피 차파차파
#   ✅ [밈 추출] 서울의 봄(전두광)[53]
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.10.2024년'
# ============================================================
#   ✅ [밈 추출] 치피치피 차파차파
#   ✅ [밈 추출] 꽁꽁 얼어붙은 한강 위로 고양이가 걸어다닙니다
#   ✅ [밈 추출] 춤추는 늑대
#   ✅ [밈 추출] 탕후루는 차갑다
#   ✅ [밈 추출] 은행 플러팅
#   ✅ [밈 추출] 투슬리스 댄스
#   ✅ [밈 추출] 국가권력급
#   ✅ [밈 추출] 밥똥던
#   ✅ [밈 추출] 한잔해
#   ✅ [밈 추출] 움파룸파춤
#   ✅ [밈 추출] 캣냅
#   ✅ [밈 추출] 브링방방
#   ✅ [밈 추출] 손흥민 축신짤
#   ✅ [밈 추출] 움파룸파춤[1월~]
#   ✅ [밈 추출] 첫 만남은 계획대로 되지 않아
#   ✅ [밈 추출] 목욕송
#   ✅ [밈 추출] 밤양갱
#   ✅ [밈 추출] AK47 맞고 사망한 외할머니
#   ✅ [밈 추출] 구구단 댄스
#   ✅ [밈 추출] 정몽규 나가
#   ✅ [밈 추출] 원영적 사고
#   ✅ [밈 추출] 야레야레 못말리는 아가씨
#   ✅ [밈 추출] 포켓몬 댄스
#   ✅ [밈 추출] 꽁꽁 얼어붙은 한강 위로[55]
#   ✅ [밈 추출] 난 대학시절 묵찌빠를 전공했단 사실
#   ✅ [밈 추출] 어디출신? - 미시시피
#   ✅ [밈 추출] HAPPY
#   ✅ [밈 추출] 어라운드 더 월드
#   ✅ [밈 추출] 좌뇌 우뇌 전두엽
#   ✅ [밈 추출] Pedro Pedro Pedro
#   ✅ [밈 추출] ㅎㅎ즐거우세요?, 맞다이로 들어와
#   ✅ [밈 추출] 원영적 사고[3월~](완전 럭키비키잖아)
#   ✅ [밈 추출] 평화누리특별자치도
#   ✅ [밈 추출] 직구 금지
#   ✅ [밈 추출] 점심을 든든히 먹어두어라 저녁은 지옥에서 먹을테니
#   ✅ [밈 추출] 마라탕후루
#   ✅ [밈 추출] 포철고 챌린지
#   ✅ [밈 추출] 경북대학교 에브리타임
#   ✅ [밈 추출] 귀여워ㅋㅋ 키스할래요?
#   ✅ [밈 추출] 정상화(팩트는 ~라는 거임)
#   ✅ [밈 추출] 수수수수퍼노바
#   ✅ [밈 추출] 푸른 산호초
#   ✅ [밈 추출] 형이랑 내기할래?
#   ✅ [밈 추출] 류정란 챌린지
#   ✅ [밈 추출] 사랑했나봐[57]
#   ✅ [밈 추출] 츠~긍슴승 승르흐르르~
#   ✅ [밈 추출] 시카노코노코노코코시탄탄
#   ✅ [밈 추출] 티라미수 케익
#   ✅ [밈 추출] 하루만 기다리면 ○○가 나와요!
#   ✅ [밈 추출] 뉴진스럽다
#   ✅ [밈 추출] 누울래?[58]
#   ✅ [밈 추출] 오물 풍선
#   ✅ [밈 추출] English or Spanish
#   ✅ [밈 추출] 폴라레티
#   ✅ [밈 추출] 정상화[5월~](신창섭)
#   ✅ [밈 추출] 네 기꺼이
#   ✅ [밈 추출] 외모 췤!
#   ✅ [밈 추출] 쿵쿵따
#   ✅ [밈 추출] 미룬이 사태
#   ✅ [밈 추출] 삐끼삐끼 춤
#   ✅ [밈 추출] 인사이드 아웃 2
#   ✅ [밈 추출] 조이는 보이
#   ✅ [밈 추출] 정상화[5월~](창팝: 다 해줬잖아
#   ✅ [밈 추출] 바로 리부트 정상화
#   ✅ [밈 추출] 이해가쏙쏙되잖아리슝좍아)
#   ✅ [밈 추출] 삐끼삐끼 춤[7월~]
#   ✅ [밈 추출] 미룬이 사태[7월~]
#   ✅ [밈 추출] 2024 파리 올림픽(유빈양 할머니)
#   ✅ [밈 추출] 퍽 아디다스
#   ✅ [밈 추출] 콘코드
#   ✅ [밈 추출] 개고기 미트볼
#   ✅ [밈 추출] 두 수 앞
#   ✅ [밈 추출] 두들 댄스
#   ✅ [밈 추출] 조이는 보이
#   ✅ [밈 추출] 티니핑
#   ✅ [밈 추출] 흑백요리사: 요리 계급 전쟁 시즌 1(최강록
#   ✅ [밈 추출] 유비빔
#   ✅ [밈 추출] 고죠 백종원)
#   ✅ [밈 추출] 제로 산소
#   ✅ [밈 추출] 마루는 강쥐
#   ✅ [밈 추출] 나쁜 답변 좋은 답변
#   ✅ [밈 추출] SPRUNKI[8월~]
#   ✅ [밈 추출] 흑백요리사: 요리 계급 전쟁 시즌 1[64][9월~](검은 장갑
#   ✅ [밈 추출] 영역 전개)
#   ✅ [밈 추출] 두들 댄스
#   ✅ [밈 추출] 반전 어둠 챌린지
#   ✅ [밈 추출] 조커: 폴리 아 되
#   ✅ [밈 추출] 피크민
#   ✅ [밈 추출] 아파트(APT)
#   ✅ [밈 추출] 터미널 댄스(실루엣 챌린지)
#   ✅ [밈 추출] N Faces
#   ✅ [밈 추출] Queen never cry
#   ✅ [밈 추출] 샹하이 로맨스
#   ✅ [밈 추출] Sigma Boy
#   ✅ [밈 추출] Wait 챌린지
#   ✅ [밈 추출] Queen never cry[11월~]
#   ✅ [밈 추출] 12.3 비상계엄 관련[67]
#   ✅ [밈 추출] 봇이지 뭐
#   ✅ [밈 추출] 샹하이 로맨스
#   ✅ [밈 추출] 시그마 보이
#   ✅ [밈 추출] 오징어 게임 2
#   ✅ [밈 추출] 나쁜 답변 좋은 답변[9월~]
#   ✅ [밈 추출] Wait 챌린지[11월~]
#
# ============================================================
# 🔍 섹션 처리 중: '7.1.11.2025년'
# ============================================================
#   ✅ [밈 추출] 괜찮아 닝닝닝닝닝[12월~]
#   ✅ [밈 추출] 내면의 기가차드
#   ✅ [밈 추출] 오징어 게임 2(얼음)[12월~]
#   ✅ [밈 추출] Chill guy[12월~]
#   ✅ [밈 추출] 쉐도우밀크 쿠키
#   ✅ [밈 추출] 랫 댄스
#   ✅ [밈 추출] ~의 리즈시절
#   ✅ [밈 추출] 중증외상센터
#   ✅ [밈 추출] 랫 댄스[1월~]
#   ✅ [밈 추출] 중증외상센터[1월~]
#   ✅ [밈 추출] AKAGE
#   ✅ [밈 추출] 미오 마오 댄스
#   ✅ [밈 추출] 도이 더 도우맨
#   ✅ [밈 추출] 죠리퐁에서 왜 죠리퐁 냄새가나지
#   ✅ [밈 추출] 햄부기햄북 햄북어
#   ✅ [밈 추출] 랫 댄스[1월~]
#   ✅ [밈 추출] 햄부기햄북 햄북어[2월~]
#   ✅ [밈 추출] 사람이 죽는다고
#   ✅ [밈 추출] 폭싹 속았수다(관식이병)
#   ✅ [밈 추출] 나니가스키
#   ✅ [밈 추출] Italian Brainrot(트랄랄레로 트랄랄라
#   ✅ [밈 추출] 봄바르디로 크로코딜로
#   ✅ [밈 추출] 퉁 퉁 퉁 퉁 퉁 퉁 퉁 퉁 퉁 사후르
#   ✅ [밈 추출] 브르르 브르르 파타핌 등)
#   ✅ [밈 추출] 나니가스키[3월~]
#   ✅ [밈 추출] Italian Brainrot(트랄랄레로 트랄랄라
#   ✅ [밈 추출] 봄바르디로 크로코딜로
#   ✅ [밈 추출] 퉁 퉁 퉁 퉁 퉁 퉁 퉁 퉁 퉁 사후르
#   ✅ [밈 추출] 브르르 브르르 파타핌등)[3월~]
#   ✅ [밈 추출] 지브리 그림
#   ✅ [밈 추출] 치킨 바나나
#   ✅ [밈 추출] 누가 범인일까?
#   ✅ [밈 추출] 나니가스키[3월~]
#   ✅ [밈 추출] Italian Brainrot(트랄랄레로 트랄랄라
#   ✅ [밈 추출] 봄바르디로 크로코딜로
#   ✅ [밈 추출] 퉁 퉁 퉁 퉁 퉁 퉁 퉁 퉁 퉁 사후르
#   ✅ [밈 추출] 브르르 브르르 파타핌 등)[3월~]
#   ✅ [밈 추출] 누가 범인일까?[4월~]
#   ✅ [밈 추출] 회장 마누라 교체 비용으로 2조를 쓰면서
#   ✅ [밈 추출] 용암치킨송
#   ✅ [밈 추출] 이집트 댄스
#   ✅ [밈 추출] 테크놀로지아
#   ✅ [밈 추출] 테크놀로지아[5월~]
#   ✅ [밈 추출] 대나무행주
#   ✅ [밈 추출] 상어가 왜이래
#   ✅ [밈 추출] 아미새
#   ✅ [밈 추출] 이라이라 챌린지
#   ✅ [밈 추출] 아저씨 구문
#   ✅ [밈 추출] 케이팝 데몬 헌터스(Golden
#   ✅ [밈 추출] Soda Pop)
#   ✅ [밈 추출] 이건 ○○ 레슨 ○○하기
#   ✅ [밈 추출] 아저씨 구문[6월~]
#   ✅ [밈 추출] 케이팝 데몬 헌터스(Golden
#   ✅ [밈 추출] Soda Pop)[6월~]
#   ✅ [밈 추출] 오징어 게임 3(도시락 다 쌌어요)[6월~]
#   ✅ [밈 추출] 이건 ○○ 레슨 ○○하기[6월~]
#   ✅ [밈 추출] 에브리바디 두 더 플랍
#   ✅ [밈 추출] 쉐이칸샹 쉐이칸샹
#   ✅ [밈 추출] 이거 AI 광고야.
#   ✅ [밈 추출] 바라밤
#   ✅ [밈 추출] 초최강 챌린지
#   ✅ [밈 추출] 부가티
#   ✅ [밈 추출] 쉐이칸샹 쉐이칸샹[7월~]
#   ✅ [밈 추출] Sybau[12월~]
#   ✅ [밈 추출] 케이팝 데몬 헌터스(Golden
#   ✅ [밈 추출] Soda Pop)[6월~]
#   ✅ [밈 추출] 바라밤[7월~]
#   ✅ [밈 추출] Galti Se Mistake
#   ✅ [밈 추출] 나노바나나 내가 이룬것들
#   ✅ [밈 추출] 잔말말고 에어컨 파워냉방으로 틀어
#   ✅ [밈 추출] 내가 그걸 모를까
#   ✅ [밈 추출] 내가 그걸 모를까[8월~]
#   ✅ [밈 추출] 왜 안봐 왜 안봐 너 내 카톡 왜 안봐
#   ✅ [밈 추출] 개웃겨서 도티 낳음
#   ✅ [밈 추출] ㅅㅋㅅ
#   ✅ [밈 추출] 돌림판
#   ✅ [밈 추출] 와 기가 막히노
#   ✅ [밈 추출] 케케크롱
#   ✅ [밈 추출] 하지마
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.해외'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.1.2012년 이전'
# ============================================================
#   ➡️  소분류 연도 업데이트: 1996년
#   ✅ [밈 추출] Dancing Baby (Baby Cha-Cha)[92]
#   ➡️  소분류 연도 업데이트: 2007년
#   ✅ [밈 추출] 5월 ~ 현재: Rickrolling
#   ✅ [밈 추출] Meatspin
#   ✅ [밈 추출] 2 Girls 1 Cup
#   ✅ [밈 추출] Cake
#   ➡️  소분류 연도 업데이트: 2008년
#   ✅ [밈 추출] Loss
#   ➡️  소분류 연도 업데이트: 2009년
#   ✅ [밈 추출] fsjal
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.2.2012년~2016년'
# ============================================================
#   ➡️  소분류 연도 업데이트: 2012년
#   ✅ [밈 추출] me gusta
#   ✅ [밈 추출] rage guy
#   ✅ [밈 추출] GANGNAM STYLE
#   ➡️  소분류 연도 업데이트: 2013년
#   ✅ [밈 추출] ayy lmao
#   ➡️  소분류 연도 업데이트: 2016년
#   ✅ [밈 추출] Drakeposting
#   ✅ [밈 추출] Ain't Got Rhythm
#   ✅ [밈 추출] Dat boi
#   ✅ [밈 추출] Arthur's fist
#   ✅ [밈 추출] TheLegend27
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.3.2017년~2018년'
# ============================================================
#   ➡️  소분류 연도 업데이트: 2017년
#   ✅ [밈 추출] Brother
#   ✅ [밈 추출] may I have some oats?
#   ✅ [밈 추출] Salt Bae
#   ✅ [밈 추출] Expanding Brain
#   ✅ [밈 추출] Trash Doves
#   ✅ [밈 추출] 🅱️
#   ✅ [밈 추출] Thank you Kanye
#   ✅ [밈 추출] Very cool!
#   ✅ [밈 추출] Fidget Spinner
#   ✅ [밈 추출] #thefloorislavachallenge
#   ✅ [밈 추출] Crash Bandicoot Woah
#   ✅ [밈 추출] Guess I'll Die
#   ✅ [밈 추출] Excuse me what the fuck
#   ✅ [밈 추출] Distracted Boyfriend
#   ✅ [밈 추출] S stands for...[93]
#   ➡️  소분류 연도 업데이트: 2018년
#   ✅ [밈 추출] Ugandan Kunckles
#   ✅ [밈 추출] Tide Pods
#   ✅ [밈 추출] Somebody Toucha My Spaghet
#   ✅ [밈 추출] Burger King Foot Lettuce
#   ✅ [밈 추출] BitConnect
#   ✅ [밈 추출] Steamed Hams
#   ✅ [밈 추출] Drake
#   ✅ [밈 추출] Where's Doorhole?
#   ✅ [밈 추출] Change My Mind
#   ✅ [밈 추출] Gru's Plan
#   ✅ [밈 추출] Peter Hurts His Knees
#   ✅ [밈 추출] Globglogabgalab
#   ✅ [밈 추출] Kird
#   ✅ [밈 추출] Walmart Yodel Boy
#   ✅ [밈 추출] I don't feel so good
#   ✅ [밈 추출] Markiplier E
#   ✅ [밈 추출] This Is America
#   ✅ [밈 추출] Bart Hits Homer With A Chair
#   ✅ [밈 추출] Yanny Or Laurel
#   ✅ [밈 추출] Is this a pigeon?
#   ✅ [밈 추출] EVERYONE IS HERE
#   ✅ [밈 추출] ligma
#   ✅ [밈 추출] Excuse me what the fuck
#   ✅ [밈 추출] Bongo Cat
#   ✅ [밈 추출] THANOS CAR
#   ✅ [밈 추출] Moth & Lamp[94]
#   ✅ [밈 추출] First Time?
#   ✅ [밈 추출] Kowalski
#   ✅ [밈 추출] Analysis
#   ✅ [밈 추출] Unexpected Sans
#   ✅ [밈 추출] Surgery On a grape
#   ✅ [밈 추출] Tik Tok (I'm Already Tracer
#   ✅ [밈 추출] Hit Or Miss)
#   ✅ [밈 추출] Day XX of No Nut November[95]
#   ✅ [밈 추출] Wanna Sprite Cranberry
#   ✅ [밈 추출] Ahh Thats Hot
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.4.2019년'
# ============================================================
#   ✅ [밈 추출] Sicko Mode or Mo Bamba
#   ✅ [밈 추출] Big Chungus
#   ✅ [밈 추출] What the Fuck Did You Just Bring Upon This Cursed Land
#   ✅ [밈 추출] Thats How Mafia Works
#   ✅ [밈 추출] Miles Morales Flirting
#   ✅ [밈 추출] Let me in!
#   ✅ [밈 추출] Shaggy
#   ✅ [밈 추출] Will Smith's Genie
#   ✅ [밈 추출] Ricardo Milos
#   ✅ [밈 추출] Florida man
#   ✅ [밈 추출] Verbalase Tetris Beatbox
#   ✅ [밈 추출] You was at the club
#   ✅ [밈 추출] 듀오링고 부엉이[96]
#   ✅ [밈 추출] Ah shit, here we go again
#   ✅ [밈 추출] Tuxedo Pooh
#   ✅ [밈 추출] We have food at home
#   ✅ [밈 추출] Unsettled Tom
#   ✅ [밈 추출] Fortnite bad
#   ✅ [밈 추출] Minecraft good
#   ✅ [밈 추출] Sonic
#   ✅ [밈 추출] Oh Shit A Rat
#   ✅ [밈 추출] Toothless Presents Himself
#   ✅ [밈 추출] Stonks
#   ✅ [밈 추출] Keanu Reeves
#   ✅ [밈 추출] They're not loot boxes
#   ✅ [밈 추출] they're surprise mechanics
#   ✅ [밈 추출] Me and the Boys
#   ✅ [밈 추출] WikiHow
#   ✅ [밈 추출] 마인크래프트 (CREEPER? AW MAN!)
#   ✅ [밈 추출] JSA에 서있는 김정은과 트럼프
#   ✅ [밈 추출] Awesome (Scatman's World)
#   ✅ [밈 추출] Gamer Girl Bath Water[97]
#   ✅ [밈 추출] Storm Area 51
#   ✅ [밈 추출] Say Sike Right Now
#   ✅ [밈 추출] CEO of racism
#   ✅ [밈 추출] Not funny
#   ✅ [밈 추출] didn't laugh
#   ✅ [밈 추출] Yeah
#   ✅ [밈 추출] this is big brain time.
#   ✅ [밈 추출] Ah yes
#   ✅ [밈 추출] enslaved (meme).
#   ✅ [밈 추출] Video games cause violence
#   ✅ [밈 추출] Beanos
#   ✅ [밈 추출] Aight
#   ✅ [밈 추출] Imma head out
#   ✅ [밈 추출] September
#   ✅ [밈 추출] Storm Area 51
#   ✅ [밈 추출] 69
#   ✅ [밈 추출] Mike Wazowski-Sulley Face Swap
#   ✅ [밈 추출] change da world my final message. Goodb ye
#   ✅ [밈 추출] Vibe Check
#   ✅ [밈 추출] average fan vs average enjoyer
#   ✅ [밈 추출] Æügh
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.5.2020년'
# ============================================================
#   ✅ [밈 추출] World War III
#   ✅ [밈 추출] Dorime
#   ✅ [밈 추출] Penis music
#   ✅ [밈 추출] Meme Man
#   ✅ [밈 추출] Financial Support
#   ✅ [밈 추출] The Sabbath of PewDiePie
#   ✅ [밈 추출] Sad Linus
#   ✅ [밈 추출] Logo City
#   ✅ [밈 추출] COVID-19
#   ✅ [밈 추출] mmm monkey
#   ✅ [밈 추출] Dog Smothering Owner[98]
#   ✅ [밈 추출] Npesta Kenos Reaction
#   ✅ [밈 추출] Coffin Dance
#   ✅ [밈 추출] The Man Behind the Slaughter
#   ✅ [밈 추출] Knuckles Meme Approved
#   ✅ [밈 추출] Hey, wanna listen to some tunes
#   ✅ [밈 추출] Mundial Ronaldinho Soccer 64
#   ✅ [밈 추출] Femboy Hooters
#   ✅ [밈 추출] Wide Putin Walking
#   ✅ [밈 추출] Xue Hua Piao Piao
#   ✅ [밈 추출] My Superhero Movie
#   ✅ [밈 추출] ばかみたい / Dame Da Ne[99][100]
#   ✅ [밈 추출] Get stick bugged lol
#   ✅ [밈 추출] Wait, it's all Ohio? (Always has been)[101]
#   ✅ [밈 추출] Are ya winning
#   ✅ [밈 추출] son?
#   ✅ [밈 추출] car shearer dance
#   ✅ [밈 추출] BOBUX
#   ✅ [밈 추출] American Cup Song
#   ✅ [밈 추출] Distraction Dance
#   ✅ [밈 추출] But If You Close Your Eyes
#   ✅ [밈 추출] Among Us[102]
#   ✅ [밈 추출] Orphan-Crushing Machine
#   ✅ [밈 추출] Da Vinci
#   ✅ [밈 추출] Limmy Waking Up
#   ✅ [밈 추출] Indihome Paket Phoenix[103]
#   ✅ [밈 추출] PET THE PEEPO
#   ✅ [밈 추출] Zero Two Dance
#   ✅ [밈 추출] Exaggerated Swagger of a Black Teen
#   ✅ [밈 추출] My Little PogChamp
#   ✅ [밈 추출] Let's Go That's Class
#   ✅ [밈 추출] Pop Cat
#   ✅ [밈 추출] Cyberpunk 2077[104]
#   ✅ [밈 추출] Lamar Roasts Franklin
#   ✅ [밈 추출] Drip Goku
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.6.2021년'
# ============================================================
#   ✅ [밈 추출] Drip goku[12월~]
#   ✅ [밈 추출] GrubHub[106]
#   ✅ [밈 추출] Bits
#   ✅ [밈 추출] 게임스탑 주가 폭등 사건[107]
#   ✅ [밈 추출] Morshu RTX
#   ✅ [밈 추출] When the Imposter is sus!
#   ✅ [밈 추출] oh no
#   ✅ [밈 추출] Refuses to elaborate further
#   ✅ [밈 추출] mmmm cow[108]
#   ✅ [밈 추출] Maiyahi
#   ✅ [밈 추출] DaBaby
#   ✅ [밈 추출] I used to roll the dice
#   ✅ [밈 추출] Ara Ara
#   ✅ [밈 추출] youtube kids be like[109]
#   ✅ [밈 추출] Think, Mark! THINK!!
#   ✅ [밈 추출] Drip Car
#   ✅ [밈 추출] SAM
#   ✅ [밈 추출] I forgor 💀
#   ✅ [밈 추출] Gigachad
#   ✅ [밈 추출] I have family
#   ✅ [밈 추출] Lore
#   ✅ [밈 추출] Jack-O Challenge
#   ✅ [밈 추출] Squid Game
#   ✅ [밈 추출] Steve you gotta help me I'm stuck
#   ✅ [밈 추출] god
#   ✅ [밈 추출] please[110]
#   ✅ [밈 추출] Ankha Zone[111]
#   ✅ [밈 추출] Shang Abi (Dancing Asian Man)
#   ✅ [밈 추출] Snotty boy glow up
#   ✅ [밈 추출] Onigiri Dance
#   ✅ [밈 추출] Super idol的笑容
#   ✅ [밈 추출] Damn Daniel ar ar ar
#   ✅ [밈 추출] You should kill yourself Now[112]
#   ✅ [밈 추출] YONA YONA DANCE
#   ✅ [밈 추출] Christmas is next Friday / Christmas
#   ✅ [밈 추출] just a week away![113]
#   ✅ [밈 추출] Mr. Incredible Becoming Uncanny
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.7.2022년'
# ============================================================
#   ✅ [밈 추출] Mr. Incredible Becoming Uncanny[12월~]
#   ✅ [밈 추출] cupcakke
#   ✅ [밈 추출] Standing Here I Realize
#   ✅ [밈 추출] Saul Goodman 3D[115]
#   ✅ [밈 추출] Oh Boy, My Favourite Seat!
#   ✅ [밈 추출] Hatsune Miku does NOT talk to british people
#   ✅ [밈 추출] No Bitches?
#   ✅ [밈 추출] Pushin P
#   ✅ [밈 추출] Talking Ben The Dog
#   ✅ [밈 추출] Fortnite Battle Pass
#   ✅ [밈 추출] iShowSpeed Talking Ben
#   ✅ [밈 추출] There will be bloodshed[116]
#   ✅ [밈 추출] Skeleton Roasting JellyBean
#   ✅ [밈 추출] 77 + 33 = 100
#   ✅ [밈 추출] Misery x CPR x Reese's Puffs
#   ✅ [밈 추출] Jamie Big Sorrel Horse
#   ✅ [밈 추출] Will Smith Slapping Chris Rock
#   ✅ [밈 추출] Guys look a birdie
#   ✅ [밈 추출] Quandale dingle (goofy ahh)
#   ✅ [밈 추출] Anya Forger Face
#   ✅ [밈 추출] The Backrooms
#   ✅ [밈 추출] Terrified Noot Noot
#   ✅ [밈 추출] It's Morbin Time
#   ✅ [밈 추출] My Dog Stepped On a Bee
#   ✅ [밈 추출] turi ip ip ip[117]
#   ✅ [밈 추출] Blue Lobster Jumpscare[118]
#   ✅ [밈 추출] My reaction to that information[119]
#   ✅ [밈 추출] Nextbot
#   ✅ [밈 추출] Exposed Nerve
#   ✅ [밈 추출] Squidward kicks of his house
#   ✅ [밈 추출] Sad Cat Dance[120]
#   ✅ [밈 추출] Sims cat break-dancing
#   ✅ [밈 추출] Demon core
#   ✅ [밈 추출] YOU IS A
#   ✅ [밈 추출] Kratos Falling
#   ✅ [밈 추출] WHAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAT
#   ✅ [밈 추출] WHAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAT[7월~]
#   ✅ [밈 추출] Nanomachines, son!
#   ✅ [밈 추출] Top 5 series
#   ✅ [밈 추출] Spinning rat
#   ✅ [밈 추출] VS 놀이[122]
#   ✅ [밈 추출] Dr. Livesey phonk walk[123]
#   ✅ [밈 추출] California Gurls
#   ✅ [밈 추출] Trollge
#   ✅ [밈 추출] Vergil Status[124]
#   ✅ [밈 추출] Zyzz[125]
#   ✅ [밈 추출] One Piece Is Real[126]
#   ✅ [밈 추출] Slander
#   ✅ [밈 추출] Cooking videos[127]
#   ✅ [밈 추출] Gigachad
#   ✅ [밈 추출] Gigachad
#   ✅ [밈 추출] Mutsuki Dance
#   ✅ [밈 추출] Alphabet Lore[128]
#   ✅ [밈 추출] Wise Mystical Tree
#   ✅ [밈 추출] 사이버펑크: 엣지러너[129]
#   ✅ [밈 추출] Dream face revealed
#   ✅ [밈 추출] Baller
#   ✅ [밈 추출] Only in Ohio[130]
#   ✅ [밈 추출] No Nut November
#   ✅ [밈 추출] Mississippi Queen[131]
#   ✅ [밈 추출] Satsuki ask
#   ✅ [밈 추출] Zero Two Dodging
#   ✅ [밈 추출] Sinner's hand[132]
#   ✅ [밈 추출] Ghost stare
#   ✅ [밈 추출] Koopa dance
#   ✅ [밈 추출] The Lightskin Stare
#   ✅ [밈 추출] Mario Movie Trailer
#   ✅ [밈 추출] chip[133]
#   ✅ [밈 추출] Phonk Epic Battle
#   ✅ [밈 추출] Choo-Choo Charles
#   ✅ [밈 추출] xQc goes from happy to sad
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.8.2023년'
# ============================================================
#   ✅ [밈 추출] Sigma
#   ✅ [밈 추출] KON
#   ✅ [밈 추출] Skibidi Bob Yes Yes[134]
#   ✅ [밈 추출] Waffle House chair[135]
#   ✅ [밈 추출] Wednesday[136]
#   ✅ [밈 추출] Maxwell cat[137]
#   ✅ [밈 추출] Let me do it for you[138]
#   ✅ [밈 추출] The boys
#   ✅ [밈 추출] Boykisser[139]
#   ✅ [밈 추출] da biggest bird[140]
#   ✅ [밈 추출] Death Meme
#   ✅ [밈 추출] Oklahoma
#   ✅ [밈 추출] Toca Toca
#   ✅ [밈 추출] Noor
#   ✅ [밈 추출] Excuse me brah
#   ✅ [밈 추출] Listening to ~ be like[141]
#   ✅ [밈 추출] Whopper Whopper
#   ✅ [밈 추출] Metal Pipe Falling
#   ✅ [밈 추출] Animan Studios[142]
#   ✅ [밈 추출] Maxwell the cat[1월~]
#   ✅ [밈 추출] Lario
#   ✅ [밈 추출] Cammy Stretch
#   ✅ [밈 추출] Waffle falling over
#   ✅ [밈 추출] Biden & Trump Plays[144]
#   ✅ [밈 추출] Bruce Wang
#   ✅ [밈 추출] Atomic Heart
#   ✅ [밈 추출] Singing Killed My Grandma
#   ✅ [밈 추출] Opila Bird
#   ✅ [밈 추출] unstoppable
#   ✅ [밈 추출] Makeba
#   ✅ [밈 추출] Fake Mr. Beast
#   ✅ [밈 추출] Jedi Killer
#   ✅ [밈 추출] I'm Only Human
#   ✅ [밈 추출] Wolf jumpscare
#   ✅ [밈 추출] John Pork
#   ✅ [밈 추출] Balenciaga AI Video
#   ✅ [밈 추출] Serbian dancing lady
#   ✅ [밈 추출] goku prowler
#   ✅ [밈 추출] Bronze age shitpost
#   ✅ [밈 추출] My Heart Is Cold
#   ✅ [밈 추출] Buckle
#   ✅ [밈 추출] Give me candy
#   ✅ [밈 추출] アイドル
#   ✅ [밈 추출] Mike O'hearn
#   ✅ [밈 추출] Peaches
#   ✅ [밈 추출] Pizza Tower Screaming
#   ✅ [밈 추출] Minecraft Dirt Block Guy
#   ✅ [밈 추출] woah pipe bomb
#   ✅ [밈 추출] Which one is not sleeping[145]
#   ✅ [밈 추출] I am a surgeon
#   ✅ [밈 추출] happy cat
#   ✅ [밈 추출] Waffled
#   ✅ [밈 추출] Adam Warlock flying
#   ✅ [밈 추출] Babies Do Idol Dance
#   ✅ [밈 추출] This is a
#   ✅ [밈 추출] Brawl Stars Rank Up
#   ✅ [밈 추출] Banana Cat
#   ✅ [밈 추출] Absolute Cinema
#   ✅ [밈 추출] Monday Left Me Broken
#   ✅ [밈 추출] We're in Heaven
#   ✅ [밈 추출] Ambatukam
#   ✅ [밈 추출] Pride Month Demon
#   ✅ [밈 추출] Frigigigi
#   ✅ [밈 추출] Leave me alone
#   ✅ [밈 추출] Blud
#   ✅ [밈 추출] Cameraman:
#   ✅ [밈 추출] Bagel Effect
#   ✅ [밈 추출] ai sponge
#   ✅ [밈 추출] Shadow wizard money gang
#   ✅ [밈 추출] If I roll a
#   ✅ [밈 추출] Sacabambaspis
#   ✅ [밈 추출] One Two Buckle My Shoes
#   ✅ [밈 추출] John Cena Dancing with Headphones
#   ✅ [밈 추출] メフィスト
#   ✅ [밈 추출] Elephant Mario
#   ✅ [밈 추출] Poland Is Everywhere
#   ✅ [밈 추출] Nuh Uh
#   ✅ [밈 추출] The Grimace Shake
#   ✅ [밈 추출] Dog Sasuke
#   ✅ [밈 추출] Cupid
#   ✅ [밈 추출] Barpenheimer
#   ✅ [밈 추출] Ukulele Apology
#   ✅ [밈 추출] 페니 파커
#   ✅ [밈 추출] Threads
#   ✅ [밈 추출] 머스크 vs. 저커버그
#   ✅ [밈 추출] Shuffle
#   ✅ [밈 추출] Shizzy
#   ✅ [밈 추출] Skibidi Toilet
#   ✅ [밈 추출] Rainbow Friend
#   ✅ [밈 추출] Steal the Show
#   ✅ [밈 추출] Elemental
#   ✅ [밈 추출] Police I swear to god
#   ✅ [밈 추출] One must imagine Sisyphus happy
#   ✅ [밈 추출] LK-99
#   ✅ [밈 추출] On Sight Bear
#   ✅ [밈 추출] Vtuber Concert meme
#   ✅ [밈 추출] Pharao's curse
#   ✅ [밈 추출] Red Flags
#   ✅ [밈 추출] Windows Punch
#   ✅ [밈 추출] Is that gabe
#   ✅ [밈 추출] More Passion
#   ✅ [밈 추출] More Energy
#   ✅ [밈 추출] Freddy Fazbear
#   ✅ [밈 추출] Color
#   ✅ [밈 추출] IShowMeat
#   ✅ [밈 추출] Donald Trump's Mugshot
#   ✅ [밈 추출] Stock Shuffle
#   ✅ [밈 추출] Hakari Dancing
#   ✅ [밈 추출] Smurf Cat
#   ✅ [밈 추출] Strawberry Elephant
#   ✅ [밈 추출] Supïdo
#   ✅ [밈 추출] 디지털 서커스
#   ✅ [밈 추출] We live we love we lie
#   ✅ [밈 추출] Miku(oo ee oo)
#   ✅ [밈 추출] Kagura Bachi
#   ✅ [밈 추출] Polar bear 2026
#   ✅ [밈 추출] 95% of NFTs Are Worthless
#   ✅ [밈 추출] 粛聖!!ロリ神レクイエム☆[146]
#   ✅ [밈 추출] Squint Your Eyes
#   ✅ [밈 추출] Opium Bird[147]
#   ✅ [밈 추출] Sticking out your gyatt[148]
#   ✅ [밈 추출] Jubi Slide
#   ✅ [밈 추출] Gambare Gambare Senpai
#   ✅ [밈 추출] Slickback
#   ✅ [밈 추출] ALL MY FELLAS
#   ✅ [밈 추출] Uhu Cat
#   ✅ [밈 추출] ALL MY FELLAS[10월~]
#   ✅ [밈 추출] Huh cat
#   ✅ [밈 추출] The Coffin of Andy and Leyley
#   ✅ [밈 추출] jetcar24.ru
#   ✅ [밈 추출] Belligol[150]
#   ✅ [밈 추출] 9mm go bang
#   ✅ [밈 추출] Freddy Fazbear[151]
#   ✅ [밈 추출] Chica rizz
#   ✅ [밈 추출] Napoleon
#   ✅ [밈 추출] 조시 허처슨
#   ✅ [밈 추출] Sam Sulek
#   ✅ [밈 추출] Nah I'd Win
#   ✅ [밈 추출] The Frog Video
#   ✅ [밈 추출] Dream VS Gumball
#   ✅ [밈 추출] 후드 노숙자 밈
#   ✅ [밈 추출] Kawasaki
#   ✅ [밈 추출] Gotta Lock in
#   ✅ [밈 추출] I Think We're Gonna Have To Kill This Guy Steven
#   ✅ [밈 추출] Chipi Chipi Chapa Chapa
#   ✅ [밈 추출] 2 Cats Talking
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.9.2024년'
# ============================================================
#   ✅ [밈 추출] 2.2 Lobotomy
#   ✅ [밈 추출] Dancing Toothless
#   ✅ [밈 추출] Verbalase
#   ✅ [밈 추출] Dancing Wolf Meme
#   ✅ [밈 추출] Bling-Bang-Bang-Born
#   ✅ [밈 추출] Looksmaxx
#   ✅ [밈 추출] virtual sin forgiveness
#   ✅ [밈 추출] Chipi Chipi Chapa Chapa[12월~](boykisser)[153]
#   ✅ [밈 추출] Bling-Bang-Bang-Born[1월~]
#   ✅ [밈 추출] Verbalase[1월~]
#   ✅ [밈 추출] Raiden In Fortnite
#   ✅ [밈 추출] Don't leave so soon
#   ✅ [밈 추출] beat da koto nai
#   ✅ [밈 추출] gegagedigedagedago
#   ✅ [밈 추출] Bye-Bye(mewing)
#   ✅ [밈 추출] Ha Cha Cha
#   ✅ [밈 추출] Girlfriend
#   ✅ [밈 추출] Human... I remember you're
#   ✅ [밈 추출] Life or bath for dry cat
#   ✅ [밈 추출] Oiia Oiia
#   ✅ [밈 추출] Lovely Loco
#   ✅ [밈 추출] Pokémon Dance
#   ✅ [밈 추출] Arona Dance
#   ✅ [밈 추출] Sad Hamster
#   ✅ [밈 추출] Cotton Eye Joe
#   ✅ [밈 추출] Left or Right
#   ✅ [밈 추출] You are my sunshine
#   ✅ [밈 추출] how ~ works
#   ✅ [밈 추출] tengetenge
#   ✅ [밈 추출] Pure Pure
#   ✅ [밈 추출] SLAY[156]
#   ✅ [밈 추출] Piltos be Like
#   ✅ [밈 추출] Tenge Tenge
#   ✅ [밈 추출] Pedro Pedro Pedro Racoon
#   ✅ [밈 추출] Beautiful Things
#   ✅ [밈 추출] Masha Ultrafunk
#   ✅ [밈 추출] Sephiroth
#   ✅ [밈 추출] You are my sunshine[3월~]
#   ✅ [밈 추출] Pedro Pedro Pedro Racoon
#   ✅ [밈 추출] I Believe In Joe Hendry
#   ✅ [밈 추출] More Herta Please!
#   ✅ [밈 추출] Smoking Duck
#   ✅ [밈 추출] Glazing
#   ✅ [밈 추출] Duck Song
#   ✅ [밈 추출] A song about bread
#   ✅ [밈 추출] gwimbly
#   ✅ [밈 추출] America Ya
#   ✅ [밈 추출] Showers are too sensitive
#   ✅ [밈 추출] Daddy's home
#   ✅ [밈 추출] oi oi oi
#   ✅ [밈 추출] Around the World
#   ✅ [밈 추출] Big shoe lmfao
#   ✅ [밈 추출] If we being real
#   ✅ [밈 추출] silly billy
#   ✅ [밈 추출] I Go Meow
#   ✅ [밈 추출] Around the World[4월~]
#   ✅ [밈 추출] I told you Dave
#   ✅ [밈 추출] I never lose.
#   ✅ [밈 추출] LeBron James, Scream if you love
#   ✅ [밈 추출] english isn't my mother language
#   ✅ [밈 추출] BBL Drizzy
#   ✅ [밈 추출] Miku Miku Beam
#   ✅ [밈 추출] Ei ei ei I'm on vacation
#   ✅ [밈 추출] fun 2 rhyme
#   ✅ [밈 추출] Open the Door
#   ✅ [밈 추출] jodellavitanonhocapitouncazzo
#   ✅ [밈 추출] Miaw miaw miaw
#   ✅ [밈 추출] Let's go Gambling!
#   ✅ [밈 추출] Tyla Dance
#   ✅ [밈 추출] Shikanoko Dance
#   ✅ [밈 추출] Dithching School
#   ✅ [밈 추출] English or Spanish
#   ✅ [밈 추출] August 12 2036, the heat death of the universe!
#   ✅ [밈 추출] E.T is An Alien
#   ✅ [밈 추출] FUn 2 rhyME
#   ✅ [밈 추출] She’s my Alibi
#   ✅ [밈 추출] Not My Problem
#   ✅ [밈 추출] Not My Problem
#   ✅ [밈 추출] Superman Starman
#   ✅ [밈 추출] August 12 2036, the heat death of the universe!
#   ✅ [밈 추출] Freaky bob
#   ✅ [밈 추출] Fight… Fight Trump
#   ✅ [밈 추출] cute girl simply[159]
#   ✅ [밈 추출] Little John[160][161]
#   ✅ [밈 추출] Go-Getters
#   ✅ [밈 추출] Wizard gnomes
#   ✅ [밈 추출] aura
#   ✅ [밈 추출] Daten Route
#   ✅ [밈 추출] Attempted assassination of Donald Trump
#   ✅ [밈 추출] Army Dreamers
#   ✅ [밈 추출] Hai Yorokonde
#   ✅ [밈 추출] You think you just fell out of a coconut tree?
#   ✅ [밈 추출] Inside Out 2
#   ✅ [밈 추출] Ignore all previous instructions
#   ✅ [밈 추출] Republicans are weird
#   ✅ [밈 추출] Shadow Wizard Money Gang
#   ✅ [밈 추출] ei ei ei
#   ✅ [밈 추출] now a cow pretending to be a man
#   ✅ [밈 추출] Pikki Pikki Dance
#   ✅ [밈 추출] Big Dawgs
#   ✅ [밈 추출] Pikki Pikki Dance[7월~]
#   ✅ [밈 추출] Pepe Dance
#   ✅ [밈 추출] Paris Olympics(Paris Olympics Opening
#   ✅ [밈 추출] Olympic Shooter Anime)
#   ✅ [밈 추출] Dog Fish
#   ✅ [밈 추출] Crucified Minion
#   ✅ [밈 추출] Bye Bye Bye
#   ✅ [밈 추출] Have Some Chocolate Milk
#   ✅ [밈 추출] Honey Pie
#   ✅ [밈 추출] Brazilian Miku
#   ✅ [밈 추출] Maitake Dance
#   ✅ [밈 추출] Duolingo Meme
#   ✅ [밈 추출] I JUST WANNA BE YOUR SYMPHONY
#   ✅ [밈 추출] Emergency Dance
#   ✅ [밈 추출] Conan Dance
#   ✅ [밈 추출] Turkish Shooter
#   ✅ [밈 추출] Why so serious? ai
#   ✅ [밈 추출] My new character
#   ✅ [밈 추출] YAJU&U
#   ✅ [밈 추출] If you Dance I'll dance
#   ✅ [밈 추출] Brazilian Miku
#   ✅ [밈 추출] You think you just fell out of a coconut tree
#   ✅ [밈 추출] Concord
#   ✅ [밈 추출] Astro Bot
#   ✅ [밈 추출] I am Steve
#   ✅ [밈 추출] The Debate Was Cooked Again: debate trump vs harris
#   ✅ [밈 추출] Nikocado Avocado Two steps ahead
#   ✅ [밈 추출] It's time to play the game
#   ✅ [밈 추출] Symphony
#   ✅ [밈 추출] Deep Thoughts With The Deep
#   ✅ [밈 추출] mio mao lalalala
#   ✅ [밈 추출] Bouncing Yaris
#   ✅ [밈 추출] MrBeast Rizz Dance
#   ✅ [밈 추출] Wolverine
#   ✅ [밈 추출] Mentality
#   ✅ [밈 추출] doodle dance
#   ✅ [밈 추출] Running With Bigger And Bigger Lunchlys
#   ✅ [밈 추출] SPRUNKI[8월~]
#   ✅ [밈 추출] Running With Bigger And Bigger Lunchlys[9월~]
#   ✅ [밈 추출] I am Steve
#   ✅ [밈 추출] Deep Thoughts With The Deep
#   ✅ [밈 추출] I Just Lost My Dawg
#   ✅ [밈 추출] mio mao lalalala
#   ✅ [밈 추출] Joker: Folie à Deux
#   ✅ [밈 추출] Never KILL Yourself
#   ✅ [밈 추출] Maitake Dance[8월~]
#   ✅ [밈 추출] Ombrinho
#   ✅ [밈 추출] Diddy
#   ✅ [밈 추출] Baby Oil
#   ✅ [밈 추출] She Know
#   ✅ [밈 추출] Thick of it
#   ✅ [밈 추출] doodle dance
#   ✅ [밈 추출] APT.
#   ✅ [밈 추출] Hawk Tuah
#   ✅ [밈 추출] Burning Desires
#   ✅ [밈 추출] One step at a Time
#   ✅ [밈 추출] APT.[10월~]
#   ✅ [밈 추출] Hawk Tuah[10월~]
#   ✅ [밈 추출] Blender Cloth Simulation VS Faces
#   ✅ [밈 추출] Burning Desires
#   ✅ [밈 추출] Battle forte
#   ✅ [밈 추출] Election
#   ✅ [밈 추출] That feeling when knee surgery is tomorrow
#   ✅ [밈 추출] everyone looks awful from underneath
#   ✅ [밈 추출] Low taper fade
#   ✅ [밈 추출] Queen never cry
#   ✅ [밈 추출] wait you don't love me like i love you
#   ✅ [밈 추출] KOREAN FUNK
#   ✅ [밈 추출] Chill guy
#   ✅ [밈 추출] テトリス
#   ✅ [밈 추출] Queen never cry[11월~]
#   ✅ [밈 추출] Chill guy[11월~]
#   ✅ [밈 추출] Low taper fade[11월~] Apple dog
#   ✅ [밈 추출] Chinese Rapping dog
#   ✅ [밈 추출] Korean Martial Law
#   ✅ [밈 추출] Luigi Mangione[171]
#   ✅ [밈 추출] Hai Phút Hơn[172]
#   ✅ [밈 추출] Sigma Boy
#   ✅ [밈 추출] 5x30 5min/day
#   ✅ [밈 추출] king von
#   ✅ [밈 추출] Locked In Alien: What Is the Next Step of the Operation?
#   ✅ [밈 추출] Squid Game 2
#   ✅ [밈 추출] Olive Delights
#   ✅ [밈 추출] MiSide
#
# ============================================================
# 🔍 섹션 처리 중: '7.2.10.2025년'
# ============================================================
#   ✅ [밈 추출] Chill guy[11월~]
#   ✅ [밈 추출] Squid Game 2[12월~]
#   ✅ [밈 추출] 5x30 5min/day[12월~]
#   ✅ [밈 추출] Oiia Oiia(OIIA OIIA (Spinning Cat))[12월~] Chopped Chin
#   ✅ [밈 추출] I bought a property in Egypt
#   ✅ [밈 추출] Sonic AI
#   ✅ [밈 추출] Dih To Yo Crack
#   ✅ [밈 추출] Chess type beat(Rat Dance)
#   ✅ [밈 추출] I'll Give your Ten Dolla-![177]
#   ✅ [밈 추출] Eye of Rah
#   ✅ [밈 추출] 明日の私に幸あれ
#   ✅ [밈 추출] Chess type beat(Rat Dance)[1월~]
#   ✅ [밈 추출] Dih To Yo Crack[1월~]
#   ✅ [밈 추출] ts pmo
#   ✅ [밈 추출] My name is Edwin
#   ✅ [밈 추출] I'll Give your Ten Dolla-![1월~]
#   ✅ [밈 추출] What's that? What's a father?
#   ✅ [밈 추출] Man to woman, penis to vagina
#   ✅ [밈 추출] Cave Divers(Let me know)[181]
#   ✅ [밈 추출] Ai Wolf WalK
#   ✅ [밈 추출] CHICKEN BANANA
#   ✅ [밈 추출] Cave Divers(Let me know)[2월~]
#   ✅ [밈 추출] Hue Hue Hue Hue
#   ✅ [밈 추출] Subaru
#   ✅ [밈 추출] Dead Rose Emoji(🥀)
#   ✅ [밈 추출] JD Vance Edited Face Photoshops
#   ✅ [밈 추출] Sam Seder vs. 20 Trump Supporters
#   ✅ [밈 추출] i like to curse like i was raised in a barn
#   ✅ [밈 추출] Invincible War OCs
#   ✅ [밈 추출] Italian Brainrot(Tralalero Tralala
#   ✅ [밈 추출] Bombardiro Crocodillo
#   ✅ [밈 추출] Tung Tung Tung Tung Tung Tung Tung Tung Tung Sahur
#   ✅ [밈 추출] Brr Brr Patapim)
#   ✅ [밈 추출] The great meme depression
#   ✅ [밈 추출] Dan Hentschel Red Screaming
#   ✅ [밈 추출] Ashton Hall(The Morning Routine)
#   ✅ [밈 추출] 愛♡スクリ～ム！
#   ✅ [밈 추출] Guess who the killer is based on their reaction
#   ✅ [밈 추출] Italian Brainrot(Tralalero Tralala
#   ✅ [밈 추출] Bombardiro Crocodillo
#   ✅ [밈 추출] Tung Tung Tung Tung Tung Tung Tung Tung Tung Sahur
#   ✅ [밈 추출] Brr Brr Patapim)[3월~]
#   ✅ [밈 추출] 愛♡スクリ～ム！[3월~] Ghibli AI
#   ✅ [밈 추출] Happy Ghast
#   ✅ [밈 추출] Tim cheese lore
#   ✅ [밈 추출] Ishowspeed China(Super idol的笑容)
#   ✅ [밈 추출] Anxiety[185]
#   ✅ [밈 추출] 2025 Global Trade War(Trump Tariff Timeline
#   ✅ [밈 추출] Pay the tariffs)
#   ✅ [밈 추출] A Minecraft Movie(FLINT AND STEEL!
#   ✅ [밈 추출] CHICKEN JOCKEY!
#   ✅ [밈 추출] Steve's Lava Chicken
#   ✅ [밈 추출] I am Steve
#   ✅ [밈 추출] Middle aged man action figure
#   ✅ [밈 추출] The Nether
#   ✅ [밈 추출] Water Bucket Release)
#   ✅ [밈 추출] The lion rapes the small dog when it barks
#   ✅ [밈 추출] Sabrina Carpenter
#   ✅ [밈 추출] but when I win a 20v1
#   ✅ [밈 추출] Nooo La Polizia
#   ✅ [밈 추출] What They're Doing Is Very Smart But Also Very Dangerous
#   ✅ [밈 추출] gurt:yo
#   ✅ [밈 추출] 테크놀로지아
#   ✅ [밈 추출] lapwing gosling
#   ✅ [밈 추출] Melodie Height Nerf Fixed
#   ✅ [밈 추출] 1 gorilla vs 100 men
#   ✅ [밈 추출] The F students are inventors
#   ✅ [밈 추출] Rhymes with Grug
#   ✅ [밈 추출] Assumptions
#   ✅ [밈 추출] Kevin McCallister Shaking Head (Home Alone)
#   ✅ [밈 추출] Lonely Lonely I Guess
#   ✅ [밈 추출] Egypt Dance
#   ✅ [밈 추출] Finally it works(Dancing Iron Golem)
#   ✅ [밈 추출] king charles the dog
#   ✅ [밈 추출] Cable Car Emoji(🚡)
#   ✅ [밈 추출] cornball
#   ✅ [밈 추출] Employment/Job application
#   ✅ [밈 추출] GoG The Green Alien Dog
#   ✅ [밈 추출] Bugatti
#   ✅ [밈 추출] GoG The Green Alien Dog[5월~]
#   ✅ [밈 추출] Cat Shadow Trend
#   ✅ [밈 추출] You are the youngest person ever
#   ✅ [밈 추출] World war III
#   ✅ [밈 추출] K-Pop Demon Hunters(Golden
#   ✅ [밈 추출] Rumi Sniffing Kimbap
#   ✅ [밈 추출] Soda Pop)
#   ✅ [밈 추출] BOHAHAHA
#   ✅ [밈 추출] Bagas Bagas
#   ✅ [밈 추출] 💀 Skull Face
#   ✅ [밈 추출] Asgore Runs Over Dess
#   ✅ [밈 추출] Asgore Runs Over Dess[6월~]
#   ✅ [밈 추출] 💀 Skull Face[6월~]
#   ✅ [밈 추출] K-Pop Demon Hunters(Golden
#   ✅ [밈 추출] Rumi Sniffing Kimbap
#   ✅ [밈 추출] Soda Pop)[6월~]
#   ✅ [밈 추출] Indonesian boat aura farming
#   ✅ [밈 추출] Jet2 holiday
#   ✅ [밈 추출] performative
#   ✅ [밈 추출] Coldplay concert CEO incident
#   ✅ [밈 추출] Everybody do the Flop[190]
#   ✅ [밈 추출] Skebob
#   ✅ [밈 추출] Sinking town
#   ✅ [밈 추출] 67
#   ✅ [밈 추출] mustard
#   ✅ [밈 추출] K-Pop Demon Hunters(Golden
#   ✅ [밈 추출] Rumi Sniffing Kimbap
#   ✅ [밈 추출] Soda Pop)[6월~]
#   ✅ [밈 추출] He brought the audience to divine serenity in 5 seconds(Barbershop haircut)
#   ✅ [밈 추출] hold the dots and scroll
#   ✅ [밈 추출] baby fruit
#   ✅ [밈 추출] meowl(New Soul)
#   ✅ [밈 추출] Adrian’s friend group
#   ✅ [밈 추출] SCP-067
#   ✅ [밈 추출] Ahlelele ahlelas
#   ✅ [밈 추출] THUMB DANCE
#   ✅ [밈 추출] MONTAGEM
#   ✅ [밈 추출] gassy
#   ✅ [밈 추출] dudeman
#   ✅ [밈 추출] TOTR
#   ✅ [밈 추출] African movie
#   ✅ [밈 추출] w speed
#   ✅ [밈 추출] GD factory
#   ✅ [밈 추출] mother fry
#   ✅ [밈 추출] Fa Mulan
#   ✅ [밈 추출] Eggsuka
#
# ============================================================
# 🔍 섹션 처리 중: '8.기타 목록'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '9.여담'
# ============================================================
#
# ============================================================
# 🔍 섹션 처리 중: '10.관련 문서'
# ============================================================
#   ✅ [밈 추출] 인터넷 용어
#   ✅ [밈 추출] 인터넷 은어
#   ✅ [밈 추출] 인터넷 유행어: 2020년부터는 이와 관련된 용어들은 거의 밈으로 대체되었다.
#   ✅ [밈 추출] [1] 2020년 3월경 규정 개정으로 금지되어 옛말이 되었다.[2] 사실 정확하게는, Nyan Cat에 삽입된 노래는 하츠네 미쿠가 부른 게 아니라 UTAU인 모모네 모모가 부른 버전이다.[3] 나무위키에서 밈으로 분류된 예시이다.[4] 참고로 이 베이비 차차는 오리온에서 출시한 과자 베베의 사이버 아기 '짜루'로도 패러디되었다.#[5] 하지만 뭐든지 과도하면 안 좋듯 이미 한 번 만든 것을 여러 번 우려먹거나 스스로의 역량부족 등으로 인해 유입된 시청자들의 니즈를 맞춰주지 못한다면 모든 것이 원점으로 돌아갈 수도 있으니 주의하는 것이 좋다.[6] 정확히는 구미권의 밈과 다르게 동아시아권의 밈은 영상 내용을 개조한 물건이나 음MAD 등의 꽤 정교한 2차 창작을 위주로 발전하다보니 이에 밈 관련 인물에 대한 캐릭터성이 형성, 이를 토대로 다시 2차 창작이 제작되면서 밈 자체에 대한 팬덤이 형성되어 같은 밈이 10년 이상 소비되는 경우도 드물지 않다. '내가 고자라니'가 아주 좋은 예시.[7] 2020년대 이후로는 동아시아권도 서양 밈 자체가 유통되거나 토착 밈이여도 편집 효과 활용 내지는 짧은 패러디 등이 주가 되면서 서구화되고 있다. 다만 나무위키에 인터넷 밈으로 등재되는 단어들을 보면 신조어 밈은 오래 쓰이는 경우가 많다.[8] '창렬하다'가 기다려도 죽은 밈이 되지 않자 가수 김창열은 활동명을 변경하게 되었다.[9] 얘는 해외 파생밈도 아니고 국산 밈이다.[10] 특히 Bowsette[11] Breakfast with Endergirl! 밈과 Minecraft Sh-boom 밈으로 유명하다.[12] 물론 커비는 자체적으로 순화시킨다.[13] 다스 시디어스를 연기한 이언 맥디어미드의 찰진 발음으로 Dewitt!하는 게 밈이다.[14] 라더스의 몬 칼라마리족 부관으로 이름은 Shollan이다.[15] 주로 옆으로 미끄러지는 영상에서 데자부! 하는 타이밍에 맞춰 편집하는데, 드리프트가 문제가 아니라 각종 그냥 미끄러지기만 하는 영상에 때려박기도 한다.[16] 간혹 가다가 폭주하는 자동차 영상에 유로비트를 넣기도 한다. PUBG나 배틀필드에서 자동차를 운전할 때 일부러 이 노래를 트는 사람이 있기도 하다.[17] 러시아의 특수부대[18] 접착식 집속탄. 간단하게 설명하자면 설치된 표면 뒤로 수류탄 5발을 쏜다.[1월~] 19.1 19.2 19.3 19.4 19.5 19.6 19.7 19.8 19.9 19.10 19.11 1월부터 유행하기 시작한 밈[2월~] 20.1 20.2 20.3 2월부터 유행하기 시작한 밈[3월~] 21.1 21.2 21.3 21.4 21.5 21.6 21.7 21.8 21.9 3월부터 유행하기 시작한 밈[4월~] 22.1 22.2 22.3 4월부터 유행하기 시작한 밈[5월~] 23.1 23.2 23.3 23.4 23.5 5월부터 유행하기 시작한 밈[6월~] 24.1 24.2 24.3 24.4 24.5 24.6 24.7 24.8 24.9 24.10 6월부터 유행하기 시작한 밈[7월~] 25.1 25.2 25.3 25.4 25.5 25.6 25.7 7월부터 유행하기 시작한 밈[8월~] 26.1 26.2 26.3 26.4 26.5 8월부터 유행하기 시작한 밈[9월~] 27.1 27.2 27.3 27.4 9월부터 유행하기 시작한 밈[10월~] 28.1 28.2 28.3 28.4 10월부터 유행하기 시작한 밈[11월~] 29.1 29.2 29.3 29.4 29.5 29.6 29.7 11월부터 유행하기 시작한 밈[12월~] 30.1 30.2 30.3 30.4 30.5 30.6 30.7 30.8 30.9 30.10 30.11 30.12 12월부터 유행하기 시작한 밈[31] 물론 영미권 커뮤티니를 자주 접하는 커뮤니티 유저들은 해당 단어를 알고는 있었다.[32] 밈과 의미가 장확히 1:1로 대칭되는 것은 아니나 그 이전에 커뮤니티를 중심으로 사용된 것으론 필수요소가 있었다.[33] 밈이라는 단어가 정확히 언제부터 전해졌는지는 알 수 없으나 시기상으로 보면 스마트폰의 보급이 폭발적으로 늘어난 2010년대 초반 이후로 보여진다. 스마트폰만 있다면 누구나 24시간 인터넷을 접속할 수 있게 되었고 유튜브나 SNS 등으로 해외의 문화권을 더욱 쉽게 접할 수 있게 되었다. 또한 구글 번역기와 같이 언어의 장벽을 무너뜨리는 기능들 덕분에 해외의 유저들과 소통이 보다 쉽게 이루어지며 자연스레 국내에도 정착된 것으로 보인다.[34] 세계 무역센터 테러사건이 화재가 되었던 당시 전국 초중생 사이에서 유행하던 오사마 빈 라덴 찬양송이다. '내가 제일 존경하는 오사마 빈 라덴~ 나도 커서 이 다음에 테러범이 되고 말거야~'로 시작한다.[35] ㅋㅋ 같은 초성어는 이전에도 존재했으나, 크레이지 아케이드의 인기와 더불어 수많은 초성어가 탄생되기 시작한다.[36] 이 때부터 엽사를 필두로 한 '글자 줄여 말하기'가 본격적으로 시작되었다.[37] 애니콜 핸드폰 CF에서 나온 멘트이다.[38] 후에 등장하는 뚝배기 유행어의 고착화에도 도움을 주었다.[39] 넌 나에게 ~~를 줬어 등의 바리에이션으로 구성된다.[40] 일명 경인대첩이라 불리는, 사상 최대규모의 한일 사이버 유저 대첩이다.[41] 사실상 고자라니 다음으로 오래 살아남은 밈이다.[42] 영화 아저씨의 명대사. 자매품으로 '이거 방탄유리야 이 개새끼야'가 있다.[~2019년] [44] 코로나 19로 인해 자택근무가 일상이 되었다 보니 다른 시기에 비해 많은 인터넷 밈들이 탄생하였다.[45] 다만 같은 해의 10월 28일에 행정안전부에 의한 차단 조치를 당하면서 사실상 데이터 말소에 가까운 수준으로 사라졌다.[46] 사회 문제 해결엔 별 도움이 안되고 그저 황당함에 웃음만 나온다는 점에서 밈이 되었다.[47] 단계적 일상회복이 진행되면서 유행하는 인터넷 밈의 빈도가 작년에 비하면 많이 줄어들었지만 틱톡과 유튜브 쇼츠의 영향으로 다양한 밈들이 쏟아져 나오고 있다.[48] 처음 등장한 것은 10월이지만 본격적인 유행은 11월부터였으며, 12월 카타르 월드컵을 계기로 전국민적으로 확산되어 사실상 22년의 마지막 순간까지를 장식한 밈이다.[49] 릴스를 비롯한 숏폼 플랫폼의 영향으로 해외발 밈도 많이 역수입되었다.[51] 영화 내부자들에서 이경영의 배역 장필우의 일명 꼬탄주 대사에서 나온 밈이다. 하지만, 실제로는 이 대사가 전혀 나오지 않지만 일부러 대사가 있는 것처럼 연기하는 것이다.[52] 하이디라오 춤이라고도 불린다.[53] "실패하면 XX, 성공하면 XX 아입니까!", "그 이왕이면 XX(이)란 멋진 단어를 쓰십시오!"[55] 1월 달 유행했던 밈의 확장판으로, 멋진 외제차가 드리프트를 하거나 호날두가 슈팅연습을 하는 등 괴이한 바리에이션이 많이 생겼다. 수많은 연예인들이 이 챌린지에 참여하면서 유행하게 되었다. 인스타그램에 원본이 있으며 뉴스에도 나왔다.[57] 이 음원에 곰돌이 푸가 강남스타일을 추는 영상이 유행했다.[58] ~~유전자 섞을래?, 우리 집 코끼리 보러갈래? 귀엽네? 스껄할래? 작업실 놀러올래?[64] 나야, 들기름[67] 취했나 봄, 석열의 봄, 용산의 봄, 서울의 밤, 서울의 겨울 등[92] 주요 이메일 체인들을 통해 퍼젔다고 한다[93] Blend S 인트로 영상을 바탕으로 했다.[94] Moth는 Møth와 Möth, Lamp는 Lämp와 Læmp로 자주 쓰인다.[95] No Nut November = 11월 금딸 챌린지. 바로 뒤 12월은 Destroy Dick December라고 해서 11월에 하지 못한 것을 마음껏 푸는 달이다.[96] 이름은 Duo.[97] 벨 델핀이 목욕물을 온라인상으로 판 것이 밈화되었다.[98] 주인을 베개로 깔아뭉개는 강아지[99] 가장 오래된 영상으로 추정되는 Yandere Dev 버전.[100] 용과 같이 시리즈의 ばかみたい를 부른 영상을 사용해 딥페이크로 다양한 사람들이 부르게 하는 것이다.[101] 우주 비행사 2명이 서있는데 지구가 전부 미국 오하이오 지역으로만 가득 찬 걸 보면서 미국 국기를 붙인 비행사가 "잠깐, 전부 오하이오였어?"라며 매우 황당해하는데, 뒤의 오하이오 주기를 붙인 비행사가 그의 뒤 ...
#
# 🎉 크롤링 완료! 총 1334개의 밈을 수집했습니다.
#
# 💾 데이터가 memes_final.json 파일로 저장되었습니다.
# 💾 데이터가 memes_final.csv 파일로 저장되었습니다.
#
# 📋 수집된 데이터 샘플 (마지막 5개):
# ...
# 1331      10.관련 문서      10.관련 문서                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                인터넷 용어,인터넷 은어, 인터넷 유행어                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 1332      10.관련 문서      10.관련 문서                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                인터넷 용어,인터넷 은어, 인터넷 유행어                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 1333      10.관련 문서      10.관련 문서  [1]2020년 3월경 규정 개정으로 금지되어 옛말이 되었다.[2]사실 정확하게는, Nyan Cat에 삽입된 노래는하츠네 미쿠가 부른 게 아니라UTAU인모모네 모모가 부른 버전이다.[3]나무위키에서 밈으로 분류된 예시이다.[4]참고로 이 베이비 차차는오리온에서 출시한 과자베베의 사이버 아기 '짜루'로도 패러디되었다.#[5]하지만 뭐든지 과도하면 안 좋듯 이미 한 번 만든 것을 여러 번 우려먹거나 스스로의 역량부족 등으로 인해 유입된 시청자들의 니즈를 맞춰주지 못한다면 모든 것이 원점으로 돌아갈 수도 있으니 주의하는 것이 좋다.[6]정확히는 구미권의 밈과 다르게 동아시아권의 밈은 영상 내용을 개조한 물건이나음MAD등의 꽤 정교한 2차 창작을 위주로 발전하다보니 이에 밈 관련 인물에 대한 캐릭터성이 형성, 이를 토대로 다시 2차 창작이 제작되면서 밈 자체에 대한 팬덤이 형성되어 같은 밈이 10년 이상 소비되는 경우도 드물지 않다. '내가 고자라니'가 아주 좋은 예시.[7]2020년대 이후로는 동아시아권도 서양 밈 자체가 유통되거나 토착 밈이여도 편집 효과 활용 내지는 짧은 패러디 등이 주가 되면서 서구화되고 있다. 다만 나무위키에 인터넷 밈으로 등재되는 단어들을 보면 신조어 밈은 오래 쓰이는 경우가 많다.[8]'창렬하다'가 기다려도 죽은 밈이 되지 않자 가수 김창열은 활동명을 변경하게 되었다.[9]얘는 해외 파생밈도 아니고 국산 밈이다.[10]특히 Bowsette[11]Breakfast with Endergirl! 밈과 Minecraft Sh-boom 밈으로 유명하다.[12]물론 커비는 자체적으로 순화시킨다.[13]다스 시디어스를 연기한이언 맥디어미드의 찰진 발음으로Dewitt!하는 게 밈이다.[14]라더스의 몬 칼라마리족 부관으로 이름은Shollan이다.[15]주로 옆으로 미끄러지는 영상에서 데자부! 하는 타이밍에 맞춰 편집하는데, 드리프트가 문제가 아니라 각종 그냥 미끄러지기만 하는 영상에 때려박기도 한다.[16]간혹 가다가 폭주하는 자동차 영상에 유로비트를 넣기도 한다.PUBG나배틀필드에서 자동차를 운전할 때 일부러 이 노래를 트는 사람이 있기도 하다.[17]러시아의 특수부대[18]접착식 집속탄. 간단하게 설명하자면설치된 표면 뒤로 수류탄 5발을 쏜다.[1월~]19.119.219.319.419.519.619.719.819.919.1019.111월부터 유행하기 시작한 밈[2월~]20.120.220.32월부터 유행하기 시작한 밈[3월~]21.121.221.321.421.521.621.721.821.93월부터 유행하기 시작한 밈[4월~]22.122.222.34월부터 유행하기 시작한 밈[5월~]23.123.223.323.423.55월부터 유행하기 시작한 밈[6월~]24.124.224.324.424.524.624.724.824.924.106월부터 유행하기 시작한 밈[7월~]25.125.225.325.425.525.625.77월부터 유행하기 시작한 밈[8월~]26.126.226.326.426.58월부터 유행하기 시작한 밈[9월~]27.127.227.327.49월부터 유행하기 시작한 밈[10월~]28.128.228.328.410월부터 유행하기 시작한 밈[11월~]29.129.229.329.429.529.629.711월부터 유행하기 시작한 밈[12월~]30.130.230.330.430.530.630.730.830.930.1030.1130.1212월부터 유행하기 시작한 밈[31]물론 영미권 커뮤티니를 자주 접하는 커뮤니티 유저들은 해당 단어를 알고는 있었다.[32]밈과 의미가 장확히 1  [1] 2020년 3월경 규정 개정으로 금지되어 옛말이 되었다.[2] 사실 정확하게는, Nyan Cat에 삽입된 노래는 하츠네 미쿠가 부른 게 아니라 UTAU인 모모네 모모가 부른 버전이다.[3] 나무위키에서 밈으로 분류된 예시이다.[4] 참고로 이 베이비 차차는 오리온에서 출시한 과자 베베의 사이버 아기 '짜루'로도 패러디되었다.#[5] 하지만 뭐든지 과도하면 안 좋듯 이미 한 번 만든 것을 여러 번 우려먹거나 스스로의 역량부족 등으로 인해 유입된 시청자들의 니즈를 맞춰주지 못한다면 모든 것이 원점으로 돌아갈 수도 있으니 주의하는 것이 좋다.[6] 정확히는 구미권의 밈과 다르게 동아시아권의 밈은 영상 내용을 개조한 물건이나 음MAD 등의 꽤 정교한 2차 창작을 위주로 발전하다보니 이에 밈 관련 인물에 대한 캐릭터성이 형성, 이를 토대로 다시 2차 창작이 제작되면서 밈 자체에 대한 팬덤이 형성되어 같은 밈이 10년 이상 소비되는 경우도 드물지 않다. '내가 고자라니'가 아주 좋은 예시.[7] 2020년대 이후로는 동아시아권도 서양 밈 자체가 유통되거나 토착 밈이여도 편집 효과 활용 내지는 짧은 패러디 등이 주가 되면서 서구화되고 있다. 다만 나무위키에 인터넷 밈으로 등재되는 단어들을 보면 신조어 밈은 오래 쓰이는 경우가 많다.[8] '창렬하다'가 기다려도 죽은 밈이 되지 않자 가수 김창열은 활동명을 변경하게 되었다.[9] 얘는 해외 파생밈도 아니고 국산 밈이다.[10] 특히 Bowsette[11] Breakfast with Endergirl! 밈과 Minecraft Sh-boom 밈으로 유명하다.[12] 물론 커비는 자체적으로 순화시킨다.[13] 다스 시디어스를 연기한 이언 맥디어미드의 찰진 발음으로 Dewitt!하는 게 밈이다.[14] 라더스의 몬 칼라마리족 부관으로 이름은 Shollan이다.[15] 주로 옆으로 미끄러지는 영상에서 데자부! 하는 타이밍에 맞춰 편집하는데, 드리프트가 문제가 아니라 각종 그냥 미끄러지기만 하는 영상에 때려박기도 한다.[16] 간혹 가다가 폭주하는 자동차 영상에 유로비트를 넣기도 한다. PUBG나 배틀필드에서 자동차를 운전할 때 일부러 이 노래를 트는 사람이 있기도 하다.[17] 러시아의 특수부대[18] 접착식 집속탄. 간단하게 설명하자면 설치된 표면 뒤로 수류탄 5발을 쏜다.[1월~] 19.1 19.2 19.3 19.4 19.5 19.6 19.7 19.8 19.9 19.10 19.11 1월부터 유행하기 시작한 밈[2월~] 20.1 20.2 20.3 2월부터 유행하기 시작한 밈[3월~] 21.1 21.2 21.3 21.4 21.5 21.6 21.7 21.8 21.9 3월부터 유행하기 시작한 밈[4월~] 22.1 22.2 22.3 4월부터 유행하기 시작한 밈[5월~] 23.1 23.2 23.3 23.4 23.5 5월부터 유행하기 시작한 밈[6월~] 24.1 24.2 24.3 24.4 24.5 24.6 24.7 24.8 24.9 24.10 6월부터 유행하기 시작한 밈[7월~] 25.1 25.2 25.3 25.4 25.5 25.6 25.7 7월부터 유행하기 시작한 밈[8월~] 26.1 26.2 26.3 26.4 26.5 8월부터 유행하기 시작한 밈[9월~] 27.1 27.2 27.3 27.4 9월부터 유행하기 시작한 밈[10월~] 28.1 28.2 28.3 28.4 10월부터 유행하기 시작한 밈[11월~] 29.1 29.2 29.3 29.4 29.5 29.6 29.7 11월부터 유행하기 시작한 밈[12월~] 30.1 30.2 30.3 30.4 30.5 30.6 30.7 30.8 30.9 30.10 30.11 30.12 12월부터 유행하기 시작한 밈[31] 물론 영미권 커뮤티니를 자주 접하는 커뮤니티 유저들은 해당 단어를 알고는 있었다.[32] 밈과 의미가 장확히 1:1로 대칭되는 것은 아니나 그 이전에 커뮤니티를 중심으로 사용된 것으론 필수요소가 있었다.[33] 밈이라는 단어가 정확히 언제부터 전해졌는지는 알 수 없으나 시기상으로 보면 스마트폰의 보급이 폭발적으로 늘어난 2010년대 초반 이후로 보여진다. 스마트폰만 있다면 누구나 24시간 인터넷을 접속할 수 있게 되었고 유튜브나 SNS 등으로 해외의 문화권을 더욱 쉽게 접할 수 있게 되었다. 또한 구글 번역기와 같이 언어의 장벽을 무너뜨리는 기능들 덕분에 해외의 유저들과 소통이 보다 쉽게 이루어지며 자연스레 국내에도 정착된 것으로 보인다.[34] 세계 무역센터 테러사건이 화재가 되었던 당시 전국 초중생 사이에서 유행 ...

# %%
import json
import re
import pandas as pd

def clean_year_prefix(text_string):
    """
    문자열에서 연도 앞의 숫자/점 접두사를 제거하는 함수.
    e.g., "1. 2023" -> "2023"
    
    Args:
        text_string (str): 정리할 원본 문자열.

    Returns:
        str: 접두사가 제거된 문자열.
    """
    if not isinstance(text_string, str):
        return text_string # 문자열이 아니면 그대로 반환

    # 정규표현식으로 '19' 또는 '20'으로 시작하는 첫 4자리 숫자를 찾음
    match = re.search(r'(19|20)\d{2}', text_string)
    
    if match:
        # 연도를 찾았다면, 그 위치부터 문자열을 잘라내어 반환
        return text_string[match.start():]
    else:
        # 연도 패턴을 찾지 못하면 원본 값을 그대로 반환
        return text_string

def remove_brackets(text_string):
    """
    문자열에서 대괄호([])와 그 안의 내용을 모두 제거하는 함수.
    e.g., "좋은 답변[9월~]" -> "좋은 답변"
    
    Args:
        text_string (str): 정리할 원본 문자열.

    Returns:
        str: 대괄호와 내용이 제거된 문자열.
    """
    if not isinstance(text_string, str):
        return text_string # 문자열이 아니면 그대로 반환
    
    # 정규표현식을 사용하여 '[...]' 패턴을 찾아 제거하고, 양쪽 공백도 제거
    return re.sub(r'\[.*?\]', '', text_string).strip()

def clean_json_data(input_filename="memes_final.json", output_filename="memes_cleaned.json"):
    """
    JSON 파일을 읽어 다음 규칙에 따라 데이터를 정제하고 새 파일로 저장합니다.
    1. 'year_main', 'year_sub' 필드의 숫자/점 접두사를 제거합니다.
    2. 모든 텍스트 필드에서 대괄호([])와 그 안의 내용을 제거합니다.
    3. 'year_main'이 "2012년 이전"인 데이터부터 'region': '해외' 필드를, 그 이전 데이터에는 'region': '국내' 필드를 추가합니다.
    """
    try:
        # 1. 원본 JSON 파일 불러오기
        with open(input_filename, 'r', encoding='utf-8') as f:
            data = json.load(f)
        print(f"✅ '{input_filename}' 파일에서 총 {len(data)}개의 데이터를 불러왔습니다.")

    except FileNotFoundError:
        print(f"❌ 오류: '{input_filename}' 파일을 찾을 수 없습니다. 파일명을 확인해주세요.")
        return

    cleaned_data = []
    is_overseas_section = False # 해외 밈 섹션 시작을 추적하는 플래그

    # 2. 데이터 필터링 및 수정
    for item in data:
        updated_item = item.copy()

        # "2012년 이전" 항목을 처음 만나면 플래그를 True로 설정
        if not is_overseas_section and item.get('year_main') == '2012년 이전':
            is_overseas_section = True
        
        # 플래그 상태에 따라 'region' 필드 추가
        if is_overseas_section:
            updated_item['region'] = '해외'
        else:
            updated_item['region'] = '국내'
        
        # 'year_main'과 'year_sub' 필드에 접두사 정제 함수 우선 적용
        if 'year_main' in updated_item:
            updated_item['year_main'] = clean_year_prefix(item.get('year_main'))
        if 'year_sub' in updated_item:
            updated_item['year_sub'] = clean_year_prefix(item.get('year_sub'))
        
        # 모든 필드를 순회하며, 값이 문자열인 경우 대괄호 제거 함수 적용
        for key, value in updated_item.items():
            if isinstance(value, str):
                updated_item[key] = remove_brackets(value)
        
        cleaned_data.append(updated_item)

    # 3. 수정된 데이터를 새로운 JSON 파일로 저장
    with open(output_filename, 'w', encoding='utf-8') as f:
        json.dump(cleaned_data, f, ensure_ascii=False, indent=2)

    print(f"🎉 데이터 정제 완료! 결과가 '{output_filename}' 파일에 저장되었습니다.")
    
    # 4. (선택) 수정된 결과 일부를 DataFrame으로 확인
    if cleaned_data:
        print("\n--- 수정된 데이터 샘플 (국내/해외 경계) ---")
        df = pd.DataFrame(cleaned_data)
        # 'region' 필드가 국내/해외로 나뉘는 지점을 확인하기 위해 경계 데이터 출력
        try:
            # '해외' 리전이 시작되는 첫 인덱스를 찾음
            first_overseas_index = df[df['region'] == '해외'].index[0]
            start_index = max(0, first_overseas_index - 3)
            end_index = min(len(df), first_overseas_index + 3)
            print(df.iloc[start_index:end_index].to_string())
        except IndexError:
            # '해외' 데이터가 없는 경우 (또는 모든 데이터가 '해외'인 경우)
            print(df.head().to_string())


# --- 메인 실행 블록 ---
if __name__ == "__main__":
    # input_filename에 실제 파일명을 입력하여 실행하세요.
    clean_json_data(input_filename="memes_cleaned.json")
# Out:
# ✅ 'memes_cleaned.json' 파일에서 총 1327개의 데이터를 불러왔습니다.
# 🎉 데이터 정제 완료! 결과가 'memes_cleaned.json' 파일에 저장되었습니다.
#
# --- 수정된 데이터 샘플 (국내/해외 경계) ---
#     year_main year_sub   month                        title                                                                   related_links                  crawled_at region
# 596     2025년    2025년      9월                     와 기가 막히노                                                                              {}  2025-09-19T18:44:12.810255     국내
# 597     2025년    2025년      9월                         케케크롱                                                                              {}  2025-09-19T18:44:12.810255     국내
# 598     2025년    2025년      9월                          하지마                      {"하지마": "https://namu.wiki/w/%ED%95%98%EC%A7%80%EB%A7%88"}  2025-09-19T18:44:12.810255     국내
# 599  2012년 이전    1996년   8~12월  Dancing Baby (Baby Cha-Cha)  {"Dancing Baby (Baby Cha-Cha)": "https://knowyourmeme.com/memes/dancing-baby"}  2025-09-19T18:44:13.018884     해외
# 600  2012년 이전    2007년  5월 ~현재         5월 ~ 현재: Rickrolling          {"Rickrolling": "https://namu.wiki/w/Never%20Gonna%20Give%20You%20Up"}  2025-09-19T18:44:13.019393     해외
# 601  2012년 이전    2007년      7월                     Meatspin        {"Meatspin": "https://namu.wiki/w/%EB%AF%B8%ED%8A%B8%EC%8A%A4%ED%95%80"}  2025-09-19T18:44:13.019393     해외

# %%
API_KEY = "AIzaSyB3z2P1CYI1sEh4AtgbJe-6NDB8lYlJi5M"
SEARCH_ENGINE_ID = "41f14a1f733694566"

# %%
import os
import requests
from bs4 import BeautifulSoup
from googleapiclient.discovery import build

def google_web_search(search_term, api_key, cx, num_results=10):
    """
    Google API를 사용하여 웹 검색 결과를 가져옵니다.
    """
    try:
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(q=search_term, cx=cx, num=num_results).execute()
        return res.get('items', [])
    except Exception as e:
        print(f"Google 웹 검색 API 오류: {e}")
        return []

def google_image_search(search_term, api_key, cx, num_results=3):
    """
    ✨ Google API를 사용하여 이미지 검색 결과를 가져옵니다.
    """
    try:
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=search_term,
            cx=cx,
            searchType='image', # <-- 이미지 검색을 위한 핵심 옵션
            num=num_results
        ).execute()
        return res.get('items', [])
    except Exception as e:
        print(f"Google 이미지 검색 API 오류: {e}")
        return []


def scrape_page_content(url):
    """
    주어진 URL의 웹 페이지에 접속하여 본문 텍스트를 스크레이핑합니다.
    """
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        paragraphs = soup.find_all('p')
        full_text = "\n".join([p.get_text(strip=True) for p in paragraphs])
        
        return full_text if full_text else "본문 내용을 추출할 수 없습니다."

    except requests.exceptions.RequestException as e:
        return f"페이지에 접속할 수 없습니다: {e}"
    except Exception as e:
        return f"내용을 파싱하는 중 오류 발생: {e}"


# --- 메인 스크립트 실행 ---
if __name__ == "__main__":
    meme_title = "시그마 보이"
    search_term = f"{meme_title} 밈"

    print(f"'{search_term}' 키워드로 검색을 시작합니다...")
    
    # 1단계: Google API로 웹 페이지 URL 목록 수집
    web_results = google_web_search(search_term, API_KEY, SEARCH_ENGINE_ID)
    
    # ✨ 2단계: Google API로 이미지 URL 목록 수집
    image_search_term = f"{meme_title} 밈 템플릿" # 템플릿 이미지를 찾기 위해 검색어 보강
    image_results = google_image_search(image_search_term, API_KEY, SEARCH_ENGINE_ID)

    # --- 최종 결과 출력 ---

    # 웹 페이지 결과 출력
    if not web_results:
        print("\n웹 검색 결과가 없습니다.")
    else:
        print("\n" + "="*20 + " 웹 페이지 검색 결과 " + "="*20)
        for i, result in enumerate(web_results):
            print(f"\n--- 웹 결과 #{i+1} ---")
            print(f"  - 제목: {result.get('title', 'N/A')}")
            print(f"  - 링크: {result.get('link', 'N/A')}")
            
            page_url = result.get('link')
            if page_url:
                full_content = scrape_page_content(page_url)
                print(f"  - 전체 내용 (일부): \n{full_content[:200]}...")
    
    # 이미지 결과 출력
    if not image_results:
        print("\n이미지 검색 결과가 없습니다.")
    else:
        print("\n" + "="*20 + " 이미지 검색 결과 " + "="*22)
        # 대표 이미지는 첫 번째 결과로 선정
        print(f"  - 대표 이미지: {image_results[0].get('link', 'N/A')}")
        for i, result in enumerate(image_results):
            print(f"  - 이미지 #{i+1}: {result.get('link', 'N/A')}")
            
    print("\n" + "="*58)
    print("검색 및 스크레이핑 완료.")
# Out:
# '시그마 보이 밈' 키워드로 검색을 시작합니다...
#
# ==================== 웹 페이지 검색 결과 ====================
#
# --- 웹 결과 #1 ---
#   - 제목: Sigma(밈) - 나무위키
#   - 링크: https://namu.wiki/w/Sigma(%EB%B0%88)
#   - 전체 내용 (일부):
# 이 저작물은CC BY-NC-SA 2.0 KR에 따라 이용할 수 있습니다. (단, 라이선스가 명시된 일부 문서 및 삽화 제외)기여하신 문서의 저작권은 각 기여자에게 있으며, 각 기여자는 기여하신 부분의 저작권을 갖습니다.나무위키는 백과사전이 아니며 검증되지 않았거나, 편향적이거나, 잘못된 서술이 있을 수 있습니다.나무위키는 위키위키입니다. 여러분이 직접 문서...
#
# --- 웹 결과 #2 ---
#   - 제목: '시그마 보이'가 누구 또는 뭔데? : r/Thailand
#   - 링크: https://www.reddit.com/r/Thailand/comments/1iezrza/who_or_what_is_sigma_boy/?tl=ko
#   - 전체 내용 (일부):
# 5살부터 12살까지 태국 학생들 모두 몇 달 동안 '시그마 보이'를 계속 언급하는데, 뭔 소린지 전혀 모르겠어. 태국 관련 용어인가? 그리고 검지 손가락으로 손짓도 하던데...
# Create your account and connect with a world of communities.
# Anyone can view, post, and comment to th...
#
# --- 웹 결과 #3 ---
#   - 제목: Sigma Boy - 나무위키
#   - 링크: https://namu.wiki/w/Sigma%20Boy
#   - 전체 내용 (일부):
# 이 저작물은CC BY-NC-SA 2.0 KR에 따라 이용할 수 있습니다. (단, 라이선스가 명시된 일부 문서 및 삽화 제외)기여하신 문서의 저작권은 각 기여자에게 있으며, 각 기여자는 기여하신 부분의 저작권을 갖습니다.나무위키는 백과사전이 아니며 검증되지 않았거나, 편향적이거나, 잘못된 서술이 있을 수 있습니다.나무위키는 위키위키입니다. 여러분이 직접 문서...
#
# ==================== 이미지 검색 결과 ======================
#   - 대표 이미지: https://www.tiktok.com/api/img/?itemId=7440833871194639638&location=0&aid=1988
#   - 이미지 #1: https://www.tiktok.com/api/img/?itemId=7440833871194639638&location=0&aid=1988
#   - 이미지 #2: https://media.tenor.com/rUOKT9eCe2kAAAAM/mewing-jawline.gif
#   - 이미지 #3: https://www.tiktok.com/api/img/?itemId=7492116466544708910&location=0&aid=1988
#
# ==========================================================
# 검색 및 스크레이핑 완료.
